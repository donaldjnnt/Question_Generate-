# %% [markdown]
# <a href="https://colab.research.google.com/github/donaldjnnt/Question_Generate-/blob/main/QuestGen_New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.6 MB 7.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 52.4 MB/s
# ...
#      |████████████████████████████████| 895 kB 62.0 MB/s
# ...
#      |████████████████████████████████| 636 kB 76.8 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import ProphetNetTokenizer, ProphetNetForConditionalGeneration, ProphetNetConfig

model = ProphetNetForConditionalGeneration.from_pretrained('microsoft/prophetnet-large-uncased-squad-qg')
tokenizer = ProphetNetTokenizer.from_pretrained('microsoft/prophetnet-large-uncased-squad-qg')

# %%
para1 = """Real-Time Event processing or just Event stream processing is defined as the process of taking action on a series of data points that originate from a system that continuously creates data. The term “event” points to each data point in the system, and “stream” refers to the ongoing delivery of those events."""
para2 = """Actions that are taken on those events include aggregations (e.g., sum, mean, standard deviation), analytics (e.g., predicting a future event based on patterns in the data), transformations (e.g., changing a number into a date format), enrichment (e.g., combining the data point with other data sources to create more context and meaning), and ingestion (e.g., inserting the data into a database)."""
para3 = """Real-Time Event processing works by handling a data set by one data point at a time. Rather than view data as a whole set, event stream processing is about dealing with a flow of continuously created data."""
para4 = """There are two main classes of technologies: 1) the system that stores the events, and 2) the technology that helps developers write applications that take action on the events. The former component pertains to data storage, and stores data based on a timestamp. For example, you might capture outside temperature every minute of the day and treat that as an event stream. Each “event” is the temperature measurement accompanied by the exact time of the measurement. This is often handled by technology such as Apache Kafka. The latter (known as “stream processors” or “stream processing engines”) is truly the “event stream processing” component and lets you take action on the incoming data"""
para5 = """Batch processing is defined as the process of the processing of transactions in a bunch or a group/batch. There is no user interaction is required once batch processing is underway. This differentiates batch processing from transaction processing, which involves processing transactions one at a time and requires user interaction."""
para6 = """Batch processing is a technique for automating and processing multiple transactions as a single group. Batch processing helps in handling tasks like payroll, end-of-month reconciliation, or settling trades overnight. Batch processing systems can save money and labor over time, but they may be costly to design and implement up-front."""
para7 = """Near Real-Time processing is defined as the process of the processing of transactions in a slightly slower time frame than in real-time. In Real-Time the data is streamed and processed continuously but in Near Real-Time processing there is a time delay in the data processing."""
para8 = """The demand for near real-time analysis of streaming data is increasing rapidly in scientific projects. This trend is driven by the fact that it is expensive and time-consuming to design and execute complex experiments and simulations. The increasing velocity and volume of streaming data and the multi-institutional nature of large-scale scientific projects present challenges to near real-time analysis of streaming data"""
para9 = """Real-Time Event Processing Batch Processing Definition Real-Time Event Processing is the method of processing data instantly meaning all the processing is done in one go without any time delay. In Real-Time Event Processing task completion is very crucial in a specified time frame. Real-Time Event Processing Involves complex hardware and software components involved. Task Completion Hardware/ Software Batch Processing is the method of processing large amount of data wherein similar set of transactions are put together in a group or a cluster. In Batch Processing task completion time is not imperative.. Batch Processing is a cost effective model and simplest processing method used in the business."""
para10 = """Real-Time Event Processing Batch Processing Time Delay Real-Time Event Processing is the method of processing data is instantly and no time delay is permitted. In Batch Processing the actual data processing is delay at a convenient Time. Applications Most Common Examples of RealTime Event Processing include ATM's, flight control, traffic control etc. Most Common Examples of Batch Processing include payroll and billing systems."""
para11 = """Real-Time Event Processing Near Real-Time Event Processing Definition Real-Time Event Processing is the method of processing data instantly meaning all the processing is done in one go without any time delay. Near Real-Time Processing is the method of processing data with a time delay as against Real-Time where the data is processed instatntly"""
para12 = """Real-Time Event Processing Near Real-Time Event Processing In Real-Time Event Processing the Data Processing Time and Speed is Importatnt In Near Real-Time Processing the actual data processing is with a delay at a convenient Time. Data Processing In Real-Time Event Processing task completion is very crucial in a specified time frame. Task Completion In Near Real-Time task completion time is not imperative.. Applications Most Common Examples of RealTime Event Processing include ATM's, flight control, traffic control etc. Most Common Examples of Near Real-Time Event Processing include .Processing sensor data, IT systems Monitoring, Financial Transaction Processing."""

# %%
pp = para3

CONTENT = pp

inputs = tokenizer([CONTENT], return_tensors='pt')

# Generate Summary
question_ids = model.generate(inputs['input_ids'], num_beams=1, early_stopping=True)
print("Derived Question: \n\n", tokenizer.batch_decode(question_ids, skip_special_tokens=True))
print("\n")
print("Question Derived from this Content: \n\n", pp)
# Out:
# Derived Question:
#
#  ['how does real - time event processing work?']
#
#
# Question Derived from this Content:
#
#  Real-Time Event processing works by handling a data set by one data point at a time. Rather than view data as a whole set, event stream processing is about dealing with a flow of continuously created data.

# %%
# !pip install PyPDF2
# Out:
# ...
#      |████████████████████████████████| 77 kB 4.3 MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61100 sha256=e548530190d4564595640bd27a230d94aafae7b0097f7787038c77ed6430dc7f
#   Stored in directory: /root/.cache/pip/wheels/80/1a/24/648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# ...

# %%
import PyPDF2
import itertools


def extractTextList(self):
    text_list = []
    content = self["/Contents"].getObject()
    if not isinstance(content, ContentStream):
        content = ContentStream(content, self.pdf)

    for operands, operator in content.operations:
        if operator == b_("Tj"):
            _text = operands[0]
            if isinstance(_text, TextStringObject) and len(_text.strip()):
                text_list.append(_text.strip())
        elif operator == b_("T*"):
            pass
        elif operator == b_("'"):
            pass
            _text = operands[0]
            if isinstance(_text, TextStringObject) and len(operands[0]):
                text_list.append(operands[0])
        elif operator == b_('"'):
            _text = operands[2]
            if isinstance(_text, TextStringObject) and len(_text):
                text_list.append(_text)
        elif operator == b_("TJ"):
            for i in operands[0]:
                if isinstance(i, TextStringObject) and len(i):
                    text_list.append(i)
    return text_list


from PyPDF2.pdf import PageObject, u_, ContentStream, b_, TextStringObject
PageObject.extractTextList = extractTextList


def between(text_elements, drop_while, take_while):    
    return list(itertools.takewhile(take_while, itertools.dropwhile(drop_while, text_elements)))[1:]    


pdfFileObj = open('1_Advanced Computing Defined.pdf', 'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

page0 = pdfReader.getPage(0)
text_elements = page0.extractTextList()

# %%
pdfReader

# %%
# !pip install tika
# Out:
# ...
#   Created wheel for tika: filename=tika-1.24-py3-none-any.whl size=32893 sha256=51193660934e3e4035caf5080c108d577b7793454256b9e1d331a7d9551b5c83
#   Stored in directory: /root/.cache/pip/wheels/ec/2b/38/58ff05467a742e32f67f5d0de048fa046e764e2fbb25ac93f3
# Successfully built tika
# ...

# %%
from tika import parser  
  
# opening pdf file
parsed_pdf = parser.from_file("1_Advanced Computing Defined.pdf")
  
# saving content of pdf
# you can also bring text only, by parsed_pdf['text'] 
# parsed_pdf['content'] returns string 
data = parsed_pdf['content'] 
  
# Printing of content 
print(data)
  
# <class 'str'>
print(type(data))
# Out:
# Unit-1 Advanced Computing Defined
#
# Advanced Computing
# Defined
#
# Unit - 1
#
# ©DeepSphere.AI, Inc.| Confidential and Proprietary|DeepSphere.AI | DsSchoolOfAI.Com | Info@DeepSphere.AI
#
# PAGE 1
#
#
#
# Unit-1 Advanced Computing Defined
#
# ©DeepSphere.AI, Inc.| Confidential and Proprietary|DeepSphere.AI | DsSchoolOfAI.Com | Info@DeepSphere.AI
#
# PAGE 2
#
# ©DeepSphere.AI, Inc.| Confidential and Proprietary|DeepSphere.AI | DsSchoolOfAI.Com | Info@DeepSphere.AI
#
# PAGE 2
#
# Unit Topics
#
# Computing Overview
# History of Computing
# Advanced Computing Overview
# High-Performance Computing
# High-Performance Computing Types
# Business Challenges of Advanced Computing
# Business Benefits of Advanced Computing
# Role of Advanced Computing in AI Implementation
# Lab 1: Understand and Practise Basic/Advanced
# Computing functions
# Parallel Computing overview
# Soft Computing overview
#
# The Students will gain hands-on skills, knowledge and expertise about Advanced
# ...

# %%
print(list("".join(data)))
# Out:
# ['\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', 'U', 'n', 'i', 't', '-', '1', ' ', 'A', 'd', 'v', 'a', 'n', 'c', 'e', 'd', ' ', 'C', 'o', 'm', 'p', 'u', 't', 'i', 'n', 'g', ' ', 'D', 'e', 'f', 'i', 'n', 'e', 'd', '\n', '\n', 'A', 'd', 'v', 'a', 'n', 'c', 'e', 'd', ' ', 'C', 'o', 'm', 'p', 'u', 't', 'i', 'n', 'g', '\n', 'D', 'e', 'f', 'i', 'n', 'e', 'd', '\n', '\n', 'U', 'n', 'i', 't', ' ', '-', ' ', '1', '\n', '\n', '©', 'D', 'e', 'e', 'p', 'S', 'p', 'h', 'e', 'r', 'e', '.', 'A', 'I', ',', ' ', 'I', 'n', 'c', '.', '|', ' ', 'C', 'o', 'n', 'f', 'i', 'd', 'e', 'n', 't', 'i', 'a', 'l', ' ', 'a', 'n', 'd', ' ', 'P', 'r', 'o', 'p', 'r', 'i', 'e', 't', 'a', 'r', 'y', '|', 'D', 'e', 'e', 'p', 'S', 'p', 'h', 'e', 'r', 'e', '.', 'A', 'I', ' ', '|', ' ', 'D', 's', 'S', 'c', 'h', 'o', 'o', 'l', 'O', 'f', 'A', 'I', '.', 'C', 'o', 'm', ' ', '|', ' ', 'I', 'n', 'f', 'o', '@', 'D', 'e', 'e', 'p', 'S', '
# ...

# %%
# Python code to convert string to list
  
def Convert(string):
    li = list(string.split("."))
    return li
  
# Driver code    
#str1 = "Geeks for Geeks"
print(Convert(data))
# Out:
# ['\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nUnit-1 Advanced Computing Defined\n\nAdvanced Computing\nDefined\n\nUnit - 1\n\n©DeepSphere', 'AI, Inc', '| Confidential and Proprietary|DeepSphere', 'AI | DsSchoolOfAI', 'Com | Info@DeepSphere', 'AI\n\nPAGE 1\n\n\n\nUnit-1 Advanced Computing Defined\n\n©DeepSphere', 'AI, Inc', '| Confidential and Proprietary|DeepSphere', 'AI | DsSchoolOfAI', 'Com | Info@DeepSphere', 'AI\n\nPAGE 2\n\n©DeepSphere', 'AI, Inc', '| Confidential and Proprietary|DeepSphere', 'AI | DsSchoolOfAI', 'Com | Info@DeepSphere', 'AI\n\nPAGE 2\n\nUnit Topics\n\nComputing Overview\nHistory of Computing\nAdvanced Computing Overview\nHigh-Performance Computing\nHigh-Performance Computing Types\nBusiness Challenges of Advanced Computing \nBusiness Benefits of Advanced Computing\nRole of Advanced Computing in AI Implementation\nLab 1: Understand and Practise Basic/Advanced\nComputing functions\nParallel Computing overview\nSoft Computing overview\n\nThe Students will gain
# ...

# %%
# !pip install slate3k
# Out:
# ...
#      |████████████████████████████████| 100 kB 6.9 MB/s
# ...
#      |████████████████████████████████| 49 kB 5.3 MB/s
# ...

# %%
import slate3k as slate

with open('1_Advanced Computing Defined.pdf', 'rb') as f:
    doc = slate.PDF(f)

doc
#prints the full document as a list of strings
#each element of the list is a page in the document
# Out:
# ['nit-1 A\n\ndvanced C\n\nomputing D\n\nefined\n\nUn\n\ni\n\n - 1\n\ndv an\n\nced C\n\ni\n\ng\n\nefi\n\ned\n\n© D\n\neep S phere. A\n\n, I nc.| C\n\nonfidential and P\n\nroprietary| D\n\neep S phere. A\n\n | D\n\ns S\n\nchool O\n\nf A\n\n. C\n\nom | I nfo @\n\neep S phere. A\n\nP A\n\n 1\n\nU\nA\no\nm\np\nu\nt\nn\nD\nn\nt\nI\nI\nI\nD\nI\nG\nE\n\x0c',
# ...

# %%
from PyPDF2 import PdfFileReader

# open PDF
myPDFpath = "/content/1_Advanced Computing Defined.pdf"
myPDF = PdfFileReader(open(myPDFpath, "rb"))

# initialize page list
pagelist = []

# grab all text from PDF per page and put into page list    
for page in range(0, myPDF.getNumPages()):
    currentPage = myPDF.getPage(page)
    myText = currentPage.extractText()
    thispage = myText.split()
    pagelist.append(thispage)

# %%
paras = ["""Real-Time Event processing or just Event stream processing is defined as the process of taking action on a series of data points that originate from a system that continuously creates data. The term “event” points to each data point in the system, and “stream” refers to the ongoing delivery of those events.""",
"""Actions that are taken on those events include aggregations (e.g., sum, mean, standard deviation), analytics (e.g., predicting a future event based on patterns in the data), transformations (e.g., changing a number into a date format), enrichment (e.g., combining the data point with other data sources to create more context and meaning), and ingestion (e.g., inserting the data into a database).""",
"""Real-Time Event processing works by handling a data set by one data point at a time. Rather than view data as a whole set, event stream processing is about dealing with a flow of continuously created data.""",
"""There are two main classes of technologies: 1) the system that stores the events, and 2) the technology that helps developers write applications that take action on the events. The former component pertains to data storage, and stores data based on a timestamp. For example, you might capture outside temperature every minute of the day and treat that as an event stream. Each “event” is the temperature measurement accompanied by the exact time of the measurement. This is often handled by technology such as Apache Kafka. The latter (known as “stream processors” or “stream processing engines”) is truly the “event stream processing” component and lets you take action on the incoming data""",
"""Batch processing is defined as the process of the processing of transactions in a bunch or a group/batch. There is no user interaction is required once batch processing is underway. This differentiates batch processing from transaction processing, which involves processing transactions one at a time and requires user interaction.""",
"""Batch processing is a technique for automating and processing multiple transactions as a single group. Batch processing helps in handling tasks like payroll, end-of-month reconciliation, or settling trades overnight. Batch processing systems can save money and labor over time, but they may be costly to design and implement up-front.""",
"""Near Real-Time processing is defined as the process of the processing of transactions in a slightly slower time frame than in real-time. In Real-Time the data is streamed and processed continuously but in Near Real-Time processing there is a time delay in the data processing.""",
"""The demand for near real-time analysis of streaming data is increasing rapidly in scientific projects. This trend is driven by the fact that it is expensive and time-consuming to design and execute complex experiments and simulations. The increasing velocity and volume of streaming data and the multi-institutional nature of large-scale scientific projects present challenges to near real-time analysis of streaming data""",
"""Real-Time Event Processing Batch Processing Definition Real-Time Event Processing is the method of processing data instantly meaning all the processing is done in one go without any time delay. In Real-Time Event Processing task completion is very crucial in a specified time frame. Real-Time Event Processing Involves complex hardware and software components involved. Task Completion Hardware/ Software Batch Processing is the method of processing large amount of data wherein similar set of transactions are put together in a group or a cluster. In Batch Processing task completion time is not imperative.. Batch Processing is a cost effective model and simplest processing method used in the business.""",
"""Real-Time Event Processing Batch Processing Time Delay Real-Time Event Processing is the method of processing data is instantly and no time delay is permitted. In Batch Processing the actual data processing is delay at a convenient Time. Applications Most Common Examples of RealTime Event Processing include ATM's, flight control, traffic control etc. Most Common Examples of Batch Processing include payroll and billing systems.""",
"""Real-Time Event Processing Near Real-Time Event Processing Definition Real-Time Event Processing is the method of processing data instantly meaning all the processing is done in one go without any time delay. Near Real-Time Processing is the method of processing data with a time delay as against Real-Time where the data is processed instatntly""",
"""Real-Time Event Processing Near Real-Time Event Processing In Real-Time Event Processing the Data Processing Time and Speed is Importatnt In Near Real-Time Processing the actual data processing is with a delay at a convenient Time. Data Processing In Real-Time Event Processing task completion is very crucial in a specified time frame. Task Completion In Near Real-Time task completion time is not imperative.. Applications Most Common Examples of RealTime Event Processing include ATM's, flight control, traffic control etc. Most Common Examples of Near Real-Time Event Processing include .Processing sensor data, IT systems Monitoring, Financial Transaction Processing."""
]

# %%
for p in paras:
  inputs = tokenizer([p], return_tensors='pt')

# Generate Summary
  question_ids = model.generate(inputs['input_ids'], num_beams=1, early_stopping=True)
  print("Derived Question: \n\n", tokenizer.batch_decode(question_ids, skip_special_tokens=True))
  print("\n")
  print("Question Derived from this Content: \n\n", p)
# Out:
# Derived Question:
#
#  ['what is real - time event processing?']
#
#
# Question Derived from this Content:
#
#  Real-Time Event processing or just Event stream processing is defined as the process of taking action on a series of data points that originate from a system that continuously creates data. The term “event” points to each data point in the system, and “stream” refers to the ongoing delivery of those events.
# Derived Question:
#
#  ['what actions are taken on events?']
#
#
# Question Derived from this Content:
#
#  Actions that are taken on those events include aggregations (e.g., sum, mean, standard deviation), analytics (e.g., predicting a future event based on patterns in the data), transformations (e.g., changing a number into a date format), enrichment (e.g., combining the data point with other data sources to create more context and meaning), and ingestion (e.g., inserting the data into a database).
# Derived Question:
#
# ...

# %%
paras = ["""Python is a popular open-source programming language used in a variety of applications like building artificially intelligent systems, data science models, web programming many scientific programming paradigms. Python is becoming ever more popular for building data science applications. Companies worldwide are using Python to harvest insights from their data and gain a competitive edge. Unlike other Python tutorials, this course focuses on Python specifically for data science.""",
"""To get started with Python, we need to install it first. Today's PCs and Macs come with python already installed. To check if you have python installed on a Windows PC, search in the start bar for Python or run the following on the Command Line (cmd.exe)""",
"""To check if you have python installed on a Linux or Mac, then on linux open the command line or on Mac open the Terminal and type""",
"""If you find that you do not have python installed on your computer, then you can download it for free from the following website: https://www.python.org/""",
"""Python is an interpreted programming language, this means that as a developer you write Python (.py) files in a text editor and then put those files into the python interpreter to be executed. The way to run a python file is like this on the command line""",
"""Where "helloworld.py" is the name of your python file. Let's write our first Python file, called helloworld.py, which can be done in any text editor""",
"""To test a short amount of code in python sometimes it is quickest and easiest not to write the code in a file. This is made possible because Python can be run as a command line itself. Type the following on the Windows, Mac or Linux command line""",
"""Python syntax can be executed by writing directly in the Command Line: Or by creating a python file on the server, using the .py file extension, and running it in the Command Line:""",
"""Indentation refers to the spaces at the beginning of a code line. Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important. Python uses indentation to indicate a block of code.""",
"""Comments are texts that explain a piece of written python code. They are used to make the code more readable and are used to prevent execution when testing code.""",
"""Python uses Variables to store data values. Creating Python Variables Python has no command for declaring a variable. A variable is created the moment you first assign a value to it.""",
"""Variables do not need to be declared with any particular type, and can even change type after they have been set.""",
"""In programming, the data type is an important concept. Variables store data of different types, and different types can do different things. Python has the following data types builtin by default, in these categories:""",
"""
There are three numeric types in Python:
int: Int, or integer, is a whole number, positive or negative, without decimals, of
unlimited length.
float: Float can also be scientific numbers with an "e" to indicate the power of 10.
complex: Complex numbers are written with a "j" as the imaginary part:""",
"""When working with python there will be times when you want to specify a type onto a variable. This can be done with casting. Python is an object-orientated language, and as such it uses classes to define data types, including its primitive types.""",
"""Casting in python is therefore done using constructor functions:
int() - constructs an integer number from an integer literal, a float literal (by removing all
decimals), or a string literal (providing the string represents a whole number)
float() - constructs a float number from an integer literal, a float literal or a string literal
(providing the string represents a float or an integer)
str() - constructs a string from a wide variety of data types, including strings, integer
literals and float literals
""",
"""Strings in python are surrounded by either single quotation marks or double quotation marks. hello' is the same as "hello". You can display a string literal with the print() function:""",
"""Assigning a string to a variable is done with the variable name followed by an equal sign and the string:""",
"""A for loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string). This is less like the for keyword in other programming languages, and works more like an iterator method as found in other object-orientated programming languages. With the for loop we can execute a set of statements, once for each item in a list, tuple, set etc.""",
"""With the break statement we can stop the loop before it has looped through all the items""",
"""With the continue statement we can stop the current iteration of the loop, and continue with the next:""",
"""With the while loop we can execute a set of statements as long as a condition is true.""",
"""With the break statement we can stop the loop even if the while condition is true:""",
"""Switch case is a powerful decision-making construct commonly used in modular python programming. Let us implement the Python switch case statement. When you don’t want a conditional block cluttered with multiple if conditions, then, switch case can give a cleaner way to implement control flow in your program.""",
"""Python Switch Case Implementation using Dictionary Implementing Python Switch-Case with Dynamic Functions There are two ways to implement switch-case behaviour in Python""",
"""We can create a dictionary where the key will be the case and the value will be the result. We will call the dictionary get() method with a default value to implement the scenario when there is no matching case. Let’s say we have a following if-else block.""",
"""The above implementation works with simple print statements. But, most of the time we execute some method in the if-else blocks and then the dictionary will not work as switchcase replacement. Let’s say we have the following if-else block to perform some operation on the input integer""",
"""Here the choice is mapped to the dictionary key and the input integer is mapped to the lambda function. Finally, the output of the lambda function is returned from the switch_func() call."""
]

# %%
for p in paras:
  inputs = tokenizer([p], return_tensors='pt')

# Generate Summary
  question_ids = model.generate(inputs['input_ids'], num_beams=1, early_stopping=True)
  print("Derived Question: \n\n", tokenizer.batch_decode(question_ids, skip_special_tokens=True))
  print("\n")
  print("Question Derived from this Content: \n\n", p)
# Out:
# Derived Question:
#
#  ['what is the main use of python?']
#
#
# Question Derived from this Content:
#
#  Python is a popular open-source programming language used in a variety of applications like building artificially intelligent systems, data science models, web programming many scientific programming paradigms. Python is becoming ever more popular for building data science applications. Companies worldwide are using Python to harvest insights from their data and gain a competitive edge. Unlike other Python tutorials, this course focuses on Python specifically for data science.
# Derived Question:
#
#  ['what do we need to do to get started with python?']
#
#
# Question Derived from this Content:
#
#  To get started with Python, we need to install it first. Today's PCs and Macs come with python already installed. To check if you have python installed on a Windows PC, search in the start bar for Python or run the following on the Command Line (cmd.exe)
# Derived Question:
#
# ...

# %%
paras = ["""Microservices to be defined in a simple term is an approach in which a single small ,medium or large application is comprised or made up of many loosely coupled and independently deployable smaller services. Its a Cloud Native approach that benefits a business in a huge way.""",
"""The microservices typically:
are comprised of their own technology stack, including the database and data
management services.
are able communicate with one another over a combination of REST APIs, event
streaming, and message brokers; and
are organized by business capability, with the line separating services often referred to
as a bounded context.""",
"""Microservices Architectural Style enables one to decompose the software solution into small services and each service should:
Implement a specific business functionality (feature)
Independent and running on its own process
Loosely coupled with the other services
Communicate with the other services with APIs
Have a full automated deployment plan including rollback
Have separated deployment plan so each service can be deployed separately
A clear way to be monitored regarding errors and performance
Be scaled up or down based on usage separately
Have separated code base
Have decentralized governance: no need to use the same technology stack,
frameworks or libraries. Technology diversity!
Have decentralized data scheme design: Persist its own data separately with the
suitable data storage type and scheme.
""",
"""Managing microservices gets extremely complex with their increase in number. Their management should a key area of focus before you start to build them. Mismanagement of these microservices during Transformation from the monolithic applications seems to cause extreme problems and things can go out of hand if not managed properly or well enough.""",
"""It is not easy monitoring and diagnosing several microservices supporting a single application. The Application may run into problems, and finding the root cause of the problem can be extremely tedious if you do not have a means of monitoring and tracking the path a specific request took""",
"""There is always a requirement that separate teams need agility, autonomy, and continuous delivery to be able to deliver initial releases and subsequent iterative changes. This lack of DevOps culture can bottle up releases and impact the overall time to market and the response to business requests and issues""",
"""Individual services bring down the overall system sometimes. Hence there must be a Fault tolerance at the service level, and at the overall solution, level to take care of faults that occurred. Failure cannot be avoided with the complexity of a microservices environment. Both internal and external failures should be withstood by the Microservices.""",
"""With integration and interdependencies, testing becomes more complex in a microservices environment. The testing team must be quite understandable and knowledgeable on the communication channels between services. The asynchronous aspect of microservices also makes it harder to test in lower environments.""",
"""To Any Implementation building, a fault-tolerant and robust set of microservices is imperative. More exception handling functions should be built free of issues better When more failure situations are predicted during design.""",
"""When microservices operate in parallel they are more profitable. If any of the microservice components fails then you have the option of using the other service and the application will continue to run independantly.""",
"""When the architecture of microservices is based on small components it gets easy for the development team to scale up or down based on the requirements. Microservices prove to be the best option for organizations working with various platforms and devices.""",
"""Microservices are a better choice when you plan to expand your development team as part of the functionality associated with microservice architecture is the ability to easily understand when compared to an entire monolithic application.""",
"""The Microservices approach allows the developers to choose the right tools for development that allows them to build each server utilizing a language or framework they need without affecting the communication between microservices.""",
"""As microservices work standalone one does not have to change the actual codebase for any feature changes or modifications. The developer can change one component, test it, and then deploy it individually. This helps in faster application development.""",
"""Microservices allows your application to run on any device. This enables the developers to provide fast and controlled code upgrades in the process not slowing or stopping the appslication.""",
"""Microservices based applications are fairly ambiguous and used by industries disruptively due to its flexibility and independence. Some of the Applications of Microservices are listed below:""",
"""Legacy applications refactoring: When companies decide to rebuild their IT capabilities legacy applications refactoring come to their rescue. They may want to change the functionality or add some new features, move to the cloud or just conduct global system modernization.""",
"""Applications Built on Top of Big Data, AI/ML: Applications built on top of big data require a complex data pipeline oriented architecture, e.g. data collection, processing, delivery, storage etc. Such loosely coupled units are a great fit for microservices.""",
"""Large-scale systems with complex logic: Organizations growing at a rapid pace require outstanding flexibility and scalability, which only microservices architecture exactly provides and not monolithic. Building an architecture of this kind helps them find the pain points or invoke new cutting-edge technology to make it possible.""",
"""Real-Time Data Processing Applications: The data is streamed in real-time for most industry applications like YouTube and certain e-banking applications, traffic control systems, online booking etc. These applications, execute operations in real time to deliver an spontaneous output.""",
"""Monolith as the name indicates is an architecture that is comprised of all pieces together in a single application. Monolithic architecture is centred around has a single-tiered software application in which different components combined into a single program from a single platform.""",
"""In order to effectively develop AI microservices, the development team must factor the underlying application capabilities into modular building blocks that can be deployed into cloud-native environments with minimal binding among resources. Below are the steps to be followed:""",
"""Microservice framework fundamentally changes the way server scripting is written and administered. Instead of having a single monolithic application hosting your business logic, microservices reflect the distributed systems model, where a group of application components work together. There are few best practices that one should follow to achieve an efficient microservices ecosystem devoid of unnecessary architectural complexities""",
"""The Single Responsibility Principle: The microservices should be modelled Just like a piece of code written and a class will have only a single reason to change. Not following this practice and implementing services that are subject to change for more than one business context or logic is a bad practice.""",
"""Choice of a separate data store for your microservice: We must choose the right database for our microservice needs, customize the infrastructure and storage to the data that it maintains. Typically, any other microservice that needs access to that data will only access it through the APIs that the microservice with write access has exposed.""",
"""Use asynchronous communication to achieve loose coupling: In order to avoid building a mesh of tightly coupled components, we must go for using asynchronous communication between microservices.""",
"""Use a circuit breaker to achieve fault tolerance: Your system takes forever to respond, your overall response SLAs will be impacted as the microservice is dependent on another system to provide a response. To avoid this scenario and quickly respond, one simple microservices best practice you can follow is to use a circuit breaker to timeout the external call and return a default response or an error.""",
"""Proxy your microservice requests through an API Gateway: API gateway performing the functions of API authentication, request/response logging, and throttling is the ideal option Instead of having every microservice in the system doing these for you upfront will add a lot of value. Clients calling your microservices will connect to the API Gateway instead of directly calling your service.""",
"""API changes to be backward compatible: You can safely introduce changes to your API and release them fast as long as they don’t break existing callers. This is called Backward compatibility and should a best practice while implementing microservices.""",
"""Version your microservices for breaking changes: It's not always possible to make backwards-compatible changes. When you are making a breaking change, expose a new version of your endpoint while continuing to support older versions. Consumers can choose to use the new version at their convenience"""
]

# %%
for p in paras:
  inputs = tokenizer([p], return_tensors='pt')

# Generate Summary
  question_ids = model.generate(inputs['input_ids'], num_beams=1, early_stopping=True)
  print("Derived Question: \n\n", tokenizer.batch_decode(question_ids, skip_special_tokens=True))
  print("\n")
  print("Question Derived from this Content: \n\n", p)
# Out:
# Derived Question:
#
#  ['what is a microservice?']
#
#
# Question Derived from this Content:
#
#  Microservices to be defined in a simple term is an approach in which a single small ,medium or large application is comprised or made up of many loosely coupled and independently deployable smaller services. Its a Cloud Native approach that benefits a business in a huge way.
# Derived Question:
#
#  ['what are the main components of a microservice?']
#
#
# Question Derived from this Content:
#
#  The microservices typically:
# are comprised of their own technology stack, including the database and data
# management services.
# are able communicate with one another over a combination of REST APIs, event
# streaming, and message brokers; and
# are organized by business capability, with the line separating services often referred to
# as a bounded context.
# Derived Question:
#
#  ['what does microservices allow one to do?']
#
#
# Question Derived from this Content:
#
# ...

# %%
paras = ["""GPU called a Graphics processing unit, is a specialized processor originally designed to accelerate graphics rendering.""",
"""GPUs can process many pieces of data simultaneously, making them useful for machine learning, video editing, and gaming applications. GPUs may be integrated into the computer’s CPU or offered as a discrete hardware unit. In other words, a graphics processing unit (GPU) refers to a chip or electronic circuit capable of rendering graphics for display on an electronic device. The term “GPU” is often used interchangeably with “graphics card,” though the two are different. GPUs, first introduced to the wider market in 1999, are perhaps best known for their use in providing the smooth graphics that consumers expect in modern videos and video games.""",
"""There are 16 streaming multiprocessors (SMs) in the above diagram. Each SM has 8 streaming processors (SPs). That is, we get a total of 128 SPs. Now, each SP has a MAD unit (Multiply and Addition Unit) and an additional MU (Multiply Unit). The GT200 has 240 SPs, and exceeds 1 TFLOP of processing power.""",
"""Each SP is massively threaded, and can run thousands of threads per application. The G80 card supports 768 threads per SM (note: not per SP). Since each SM has 8 SPs, each SP supports a maximum of 96 threads. Total threads that can run: 128 * 96 = 12,228. This is why these processors are called ‘massively parallel’. The G80 chips has a memory bandwidth of 86.4GB/s. It also has an 8GB/s communication channel with the CPU (4GB/s for uploading to the CPU RAM, and 4GB/s for downloading from the CPU RAM).""",
"""The graphics processing unit, or GPU, has gained worldwide popularity and become one of the most important types of computing technology, both for personal and business computing.""",
"""It is primarily designed for parallel processing and is used in a wide range of applications, including graphics and video rendering. They are best and well known for their capabilities in video gaming but are becoming more and more popular for use in creative production and artificial intelligence (AI) technologies""",
"""As history speaks GPUs were originally designed to accelerate the rendering of 3D graphics. Over time, they became more flexible and programmable, enhancing their capabilities. This allowed graphics programmers to create more interesting visual effects and realistic scenes with advanced lighting and shadowing techniques. Other developers also began to tap the power of GPUs to dramatically accelerate additional workloads in high-performance computing (HPC), deep learning, and more.""",
"""The graphics in videos and games consist of polygonal coordinates that are converted into bitmaps a process called “rendering” and then into signals that are shown on a screen. This conversion requires the Graphics Processing Unit (GPU) to have a lot of processing power, which also makes GPUs useful in machine learning, artificial intelligence, and other tasks that require a large number of complex and sophisticated computations.""",
"""A few Decades ago GPU's were just known for Gaming accelerating real-time 3-D graphical applications. But with the evolution of time GPUs were seen to have the potential of solving some of the world’s most difficult computing problems.""",
"""Video games have become more computationally intensive, with hyperrealistic graphics and vast, complicated in-game worlds. With advanced display technologies, such as 4K screens and high refresh rates, along with the rise of virtual reality gaming, demands on graphics processing are growing fast. GPUs are capable of rendering graphics in both 2D and 3D. With better graphics performance, games can be played at higher resolution, at faster frame rates, or both.""",
"""The parallel processing offered by GPUs makes it faster and easier to render video and graphics in higher-definition formats. This helps the graphic designers and video content creators who have struggled a long way that tied up computing resources and stifled creative flow.""",
"""GPUs incorporate an extraordinary amount of computational capability, they can deliver incredible acceleration in workloads that take advantage of the highly parallel nature of GPUs, such as image recognition. This makes them an ideal choice for solving complex problems using Artificial Intelligence. Many of today’s deep learning technologies rely on GPUs working in conjunction with CPUs""",
"""Performance: The Performance of a GPU system is 8 times as many operations executed per second. Advantages Memory Bandwidth: 4 times as many bytes transferred per second. Cost: 29 times as many performance per dollar. Energy: 6 times as much performance per watt. Size Efficiency: 11 times as much performance per area.""",
"""Limited User Base: Only NVIDIA G8o and onward video cards can use CUDA, thus isolating all ATI Users. Disadvantages Speed: Speeds may be bottlenecked at the bus between CPU and GPU. Research: Mainly developed for reasearchers. Underdeveloped Systems: Many powerful systems are under development.""",
"""Processing power - GPUs have more cores than CPUs to complete calculations so they can be performed in significantly less time, which improves the ability to build better analytical models and discover insights.""",
"""Memory bandwidth - Currently, flagship GPUs (732 GB/s) have significantly more memory bandwidth than CPUs (102 GB/s), enabling GPUs to access and process data at a much faster rate.""",
"""Efficiency - GPUs are claimed to be up to 10 times more efficient than CPUs in both performance versus power consumption and performance versus cost.""",
"""GPU Vs CPU GPU consumes or requires less memory than CPU. GPU CPU consumes or needs more memory than GPU CPU Memory Speed Cores GPU is faster than CPU’s speed. The speed of CPU is less than GPU’s speed GPU contains more weak cores CPU contains many minute powerful cores.""",
"""GPU CPU is suitable for serial instruction processing CPU Serial Processing Parallel Processing GPU is suitable for parallel instruction processing. CPU is not suitable for parallel instruction processing. Latency GPU emphasis on high throughput. CPU emphasis on low latency""",
"""The CUDA programming model provides an abstraction of GPU architecture that acts as a bridge between an application and its possible implementation on GPU hardware.""",
"""The host is the CPU available in the system. The system memory associated with the CPU is called host memory. The GPU is called a device and GPU memory likewise called device memory. To execute any CUDA program, there are three main steps:
Copy the input data from host memory to device memory, also known as host-to-device
transfer.
Load the GPU program and execute, caching data on-chip for performance.
Copy the results from device memory to host memory, also called device-to-host transfer.""",
"""GPU Vs TPU GPU consumes or requires less memory than CPU. GPU TPU consumes or needs more memory than GPU TPU Memory Speed Cores GPU is faster than CPU’s speed. The speed of TPU is less than GPU’s speed GPU contains more weak cores TPU contains many minute powerful cores""",
"""GPU TPU is suitable for serial instruction processing TPU Serial Processing Parallel Processing GPU is suitable for parallel instruction processing. TPU is not suitable for parallel instruction processing. Latency GPU emphasis on high throughput. TPU emphasis on low latency"""
]

# %%
for p in paras:
  inputs = tokenizer([p], return_tensors='pt')

# Generate Summary
  question_ids = model.generate(inputs['input_ids'], num_beams=1, early_stopping=True)
  print("Derived Question: \n\n", tokenizer.batch_decode(question_ids, skip_special_tokens=True))
  print("\n")
  print("Question Derived from this Content: \n\n", p)
# Out:
# Derived Question:
#
#  ['what is a gpu?']
#
#
# Question Derived from this Content:
#
#  GPU called a Graphics processing unit, is a specialized processor originally designed to accelerate graphics rendering.
# Derived Question:
#
#  ['what is gpu used for?']
#
#
# Question Derived from this Content:
#
#  GPUs can process many pieces of data simultaneously, making them useful for machine learning, video editing, and gaming applications. GPUs may be integrated into the computer’s CPU or offered as a discrete hardware unit. In other words, a graphics processing unit (GPU) refers to a chip or electronic circuit capable of rendering graphics for display on an electronic device. The term “GPU” is often used interchangeably with “graphics card,” though the two are different. GPUs, first introduced to the wider market in 1999, are perhaps best known for their use in providing the smooth graphics that consumers expect in modern videos and video games.
# Derived Question:
#
# ...

# %%
paras = ["""Cloud TPUs are available in a base configuration with 8 cores and also in larger configurations called “TPU pods” of up to 2048 cores. The extra hardware can be used to accelerate training by increasing the training batch size.""",
"""Both TPUs and GPUs perform tensor operations, TPUs are more oriented in performing large tensor operations which are frequently present in neural network training compared to 3D graphics rendering""",
"""A TPU v2 core is made of a Matrix Multiply Unit (MXU) which runs matrix multiplications and a Vector Processing Unit (VPU) for all other tasks such as activations, softmax, etc. The VPU handles float32 and int32 computations. The MXU on the other hand operates in a mixed precision 16–32 bit floating point format.""",
"""The TPU is not necessarily a complex piece of hardware and looks far more like a signal processing engine for radar applications than a standard X86-derived architecture. It is also “closer in spirit to a floating point unit coprocessor than a GPU,” despite its multitude of matrix multiplication units, Jouppi says, noting that the TPU does not have any stored program; it simply executes instructions sent from the host.""",
"""The DRAM on the TPU is operated as one unit in parallel because of the need to fetch so many weights to feed to the matrix multiplication unit (on the order of 64,000 for a sense of throughput). We asked Jouppi how the TPU scales and while it’s not clear what the upper limit is, he says anytime you’re working with an accelerator that has host software there’s going to be a bottleneck. We are still not sure how these are lashed together and to what ceiling, but we can imagine, given the need to have consistent, cheap hardware to back inference at scale, it is probably not an exotic RDMA/NVlink approach or anything in that ballpark.""",
"""Tensor Processing Unit (TPU), a custom ASIC, built specifically for machine learning and tailored for TensorFlow, can handle massive multiplications and additions for neural networks, at great speeds while reducing the use of too much power and floor space.""",
"""TPUs execute 3 main steps:
First, the parameters are loaded from memory into the matrix of multipliers and
adders.
Then, data is loaded from memory.
After every multiplication operation, the results are passed on to next multipliers while
taking summation (dot product) at the same time. It can be seen in the above
animation. The output is then given as the summation of all multiplication results
between data and parameters.
""",
"""Tensor Processing Unit (TPU) is an AI accelerator application-specific integrated circuit (ASIC) developed by Google specifically for neural network machine learning, particularly using Google's own TensorFlow software.""",
"""Google uses TPUs for Google Street View text processing and was able to find all the text in the Street View database in less than five days.""",
"""In Google Photos, an individual TPU processes over 100 million photos a day[citation needed]. It is also used in RankBrain which Google uses to provide search results.""",
"""Using TPUs offers a number of advantages in terms of increasing efficiency and speed of computation, including the following benefits:
Accelerated performance of linear algebra computation, which is used heavily in machine
learning applications.
Minimized time-to-accuracy when training large, complex neural network models: models
that previously took weeks to train can converge in hours on TPUs.
Scalable operations across different machines with their TPU servers.""",
"""An important thing to understand is that TPUs are specifically optimized to perform fast, bulky matrix multiplication. Cloud TPUs are likely to be outperformed by other platforms in workloads that are not dominated by matrix multiplication, such as:
Linear algebra programs that require frequent branching or are dominated element-wise
by algebra;
Workloads that access memory in a sparse manner;
Workloads that require high-precision arithmetic;
Neural network workloads that contain custom TensorFlow operations written in C++,
specifically, custom operations in the body of the main training loop.
""",
"""GPU TPU Speed Cost Computation The Speed is moderate with 16GB memory and 100 TFLOPS on Tesla V100 GPU. The Speed is High with 64GB memory and 180 TFLOPS of performance Expensive at $354 per training preemption on a GPU 8 Cost Efficient at $724 per training preemption. Mid to large dataset and models, Image and video processing. Applications running on CUDA and OpenCL Matrix Computations, Dense vector processing, massive datasets and huge models."""
]

# %%
for p in paras:
  inputs = tokenizer([p], return_tensors='pt')

# Generate Summary
  question_ids = model.generate(inputs['input_ids'], num_beams=1, early_stopping=True)
  print("Derived Question: \n\n", tokenizer.batch_decode(question_ids, skip_special_tokens=True))
  print("\n")
  print("Question Derived from this Content: \n\n", p)
# Out:
# Derived Question:
#
#  ['what are cloud tpus?']
#
#
# Question Derived from this Content:
#
#  Cloud TPUs are available in a base configuration with 8 cores and also in larger configurations called “TPU pods” of up to 2048 cores. The extra hardware can be used to accelerate training by increasing the training batch size.
# Derived Question:
#
#  ['do tpus and gpus perform tensor operations?']
#
#
# Question Derived from this Content:
#
#  Both TPUs and GPUs perform tensor operations, TPUs are more oriented in performing large tensor operations which are frequently present in neural network training compared to 3D graphics rendering
# Derived Question:
#
#  ['what does the mxu run?']
#
#
# Question Derived from this Content:
#
# ...

# %%
paras = ["""Site reliability engineering (SRE) is a software engineering approach to IT operations. SRE teams use the software as a tool to manage systems, solve problems, and automate operations tasks. SRE takes the tasks that have historically been done by operations teams, often manually, and instead gives them to engineers or ops teams who use software and automation to solve problems and manage production systems. SRE is a valuable practice when creating scalable and highly reliable software systems. It helps you manage large systems through code, which is more scalable and sustainable for sysadmins managing thousands or hundreds of thousands of machines.""",
"""An agreement that is signed between the user and the client about tangible metrics like uptime, responsiveness, and responsibilities is called a Service Level Agreement. These agreements are written by the company’s new business and legal teams and they represent the promises you’re making to customers and the consequences if you fail to live up to those promises. Typically, consequences include financial penalties, service credits, or license extensions.""",
"""An SLA (service level agreement) are difficult to measure and report on. These agreements are written by people who aren’t in the tech trenches themselves Challenges of SLA's: For example, an SLA may promise that teams will resolve reported issues with Product X within 24 hours. But that same SLA doesn’t spell out what happens if the client takes 24 hours to send answers or screenshots to help your team diagnose the problem""",
"""An agreement within the Service level agreement about a specific metric like uptime or Response Time is called a Service Level Objective. Hence SLO's are considered as a formal agreement between you and your customer.""",
"""SLOs get fewer critics than SLAs, they can have many issues if they’re vague, overly complicated, or impossible to measure. The key to SLOs that don’t make your engineers want to tear their hair out is simplicity and clarity. Only the most important metrics should qualify for SLO status, the objectives should be spelt out in plain language, and, as with SLAs, they should always account for issues such as client-side delays.""",
"""An Service Level Indicator) is one that measures the compliance with an SLO (service level objective). So, for example, if your SLA specifies that your systems will be available 99.95% of the time, your SLO is likely 99.95% uptime and your SLI is the actual measurement of your uptime. Maybe it’s 99.96%. Maybe 99.99%. To stay in compliance with your SLA, the SLI will need to meet or exceed the promises made in that document.""",
"""As with SLOs, the challenge of SLIs is keeping them simple, choosing the right metrics to track, and not overcomplicating IT’s job by tracking too many metrics that don’t actually matter to clients.""",
"""Every development, operations have incidents happening. It's not possible for the biggest of the biggest companies to have 100% uptime. Service Level Agreements (SLAs) should never promise 100% uptime. as it cannot be kept up. You promise 99% uptime and actually come closer to 99.5%. Perhaps you promise 99.5% uptime and actually reach 99.99% in a typical month. When this happens, it is recommended not to set the user expectations too high by constantly overshooting your promises, you consider that extra .99% an error budget time that your team can use to take risks.""",
"""An error budget is defined as the maximum amount of time that a technical system can fail without contractual consequences. For example, if your Service Level Agreement (SLA) specifies that systems will function 99.99% of the time before the business has to compensate customers for the outage, that means your error budget (or the time your systems can go down without consequences) is 52 minutes and 35 seconds per year.""",
"""Error budgets are regarded as opportunities for development teams to innovate and take risks. The Error budget can be utilized in any way they like. If the product to be launched is running flawlessly without any issues then they can launch whatever they want, whenever they want.""",
"""The SLA and the SLO's must be analyzed first. Look into the objectives have you already set for uptime or successful system requests? Then see what promises have been made to the clients? Those will dictate your error budget.""",
"""Uptimes are monitored on a monthly basis. If availability is above the number promised by the SLA/SLO, the team can release new features and take risks. If it’s below the target, releases halt until the target numbers are back on track""",
"""For effective utilization of this method effectively, you need your SLO target to be translated into real numbers. You need to calculate how many hours and minutes your 1% or .5% or .1% of allowed downtime actually translates to.""",
"""Your team has error budgets. What happens when you exceed your error budget. How can you improve your service to reach your reliability target? All these are challenges that hamper the business to the core. How to address these:""",
"""The Site reliability team has to get a lot of cooperation from the Dev team to make your target SLO more attainable. One of the most prominent ways is to roll out changes out gradually so that only a small group of users is impacted by any failures. Hence by reducing impact, a smaller percentage of your users are affected by your service missing its SLO. Or the other way is to removee single points of failure in your system. If your service is only run in a single region that could spell trouble, especially if a squirrel decides to sneak into the data centre, chew on a live power cable, start a fire and cause cataclysmic failures. Side note, this is not a joke and happens more often than you think""",
"""Increasing reliability is just not time to detect, the time to resolution, and the frequency and impact of failures, there are a number of other things that can be done to improve your reliability.""",
"""One approach is to periodically report on worst customers or worst region or another category to find cases where the error budget is not evenly distributed.""",
"""Another operational activity you can do is to provide input on the feasibility of achieving targets. It sounds good to say that you'll release x amount of changes and still keep x amount of reliability, but realistically that may not be achievable.""",
"""It's important to engage in discussion with the product teams and provide input where possible. That's not only where you'll need to work with your product teams.""",
"""In fact, you'll most likely be working closely with them to implement many reliability improvements, such as standardizing infrastructure. Software and hardware don't always play nicely together.""",
"""Product teams could be developing on certain hardware specifications and architectures. But when they push to production, they may find that some services don't work on different infrastructure. Standardizing infrastructure allows for more easily repeatable deployments and fewer surprises in production.""",
"""Or, maybe the product team wants to release a new feature but there isn't enough capacity to handle it just yet. Consulting on system design can catch reliability design issues early, which is often much cheaper than fixing them after the code's been written. Bad pushes happen, that's a fact of life""",
"""Traditional Ops often focus on planning big releases, which are much riskier due to the amount of work involved. When working in longer cycles with infrequent releases things can often become complex quite quickly. You’ll be up against hard deadlines compiled with a list of added features. Whilst the big releases look impressive, they are often an inefficient way of working. They use a cost and capacity model which looks at how much they get done for the least amount of money. The key challenge with this model is that it can be difficult to cut costs but still maintain the same capacity – which is why a lot of companies using traditional methods have to regularly outsource tasks.""",
"""DevOps is an upcoming technology that integrates both development and operations teams into a coordinated workflow such that collaboration and productivity are improved to meet business objectives. DevOps helps the business immensely enabling the business to respond to changes and meet customer needs faster. Tools and automation are of great help. Practices such as Continuous Integration and Continuous Delivery are often followed.""",
"""Traditionally, products are monolithic and release cycles are really pretty long. The developers focus on creating the software, and the team operations ensure the created software could run in a production environment. Dev is all about adding new features. Ops was about stability and availability. Between these two were the testers. DevOps brings these teams closer so that releases can happen as quickly as necessary.""",
"""Traditional Ops Dev Ops Traditional Ops often focus on planning big releases, which are much riskier due to the amount of work involved. DevOps run with smaller releases that are often much easier to understand and test – making the release a lot less risky. Manage Scheduling Traditional Ops use planning and scheduling systems, to help manage any development. DevOps is built on continuous smaller releases and automation from a dedicated team, making it much easier to schedule Data Insights Traditional Ops will typically have to get numerous different parties involved when trying to collate information and data, DevOps enables you to quickly react to data. Meaning, you won’t have to sit and scroll through pages of information""",
"""Traditional Ops Dev Ops Traditional Ops are often risk-free. The culture is built around trying not to harm the business, which results in them having a lot of pressure to get things perfect. DevOps creates a culture very different. They adopt a ‘fail early’ culture, understanding that failure is inevitable. The team believes the sooner you fail, the smaller the impact and the quicker you recover. Measure Success Traditional Ops use a cost and capacity model which looks at how much they get done for the least amount of money.. DevOps adds in ‘flow’ since new applications should be measured by the time involved Task Completion Traditional Ops often complete a task by doing their part and passing it onto the next person. DevOps focuses on creating a cross-functional team where everyone’s accountable for the task being completed""",
"""SRE team to SRE team the process of workflows, priorities, daily operations vary, all of them share a set of basic responsibilities for the service(s) they support, and adhere to the same core tenets. The SRE team is responsible for the availability, latency, performance, efficiency, change management, monitoring, emergency response, and capacity planning of their services. The SRE teams interact with their environment not only the production environment, but also the product development teams, the testing teams, the users, and so on. Those rules and work practices help to maintain the focus on engineering work, as opposed to operations work.""",
"""The Operational work for SREs is capped at 50% of the time. and the remaining time is spent on coding skills on the project work. ccomplished by monitoring the amount of operational work being done by SREs, and redirecting excess operational work to the product development teams reassigning bugs and tickets to development managers, reintegrating developers into on-call pager rotations, and so on""",
"""A way to keep track of a system’s health and availability is through Monitoring by the service owners. A classic and common approach to monitoring is done through emails by triggering an alert when that value is exceeded or that condition occurs. Monitoring should not require human intervention. Automation should do the interpreting, and humans should be notified only when they need to take action.""",
"""Humans add latency. Even if a given system experiences more actual failures, a system that can avoid emergencies that require human intervention will have higher availability than a system that requires hands-on intervention""",
"""70% of outages are due to changes in a live system. It is Imperative to have best practices and use automation to accomplish the following:
Implementing progressive rollouts.
Quickly and accurately detecting problems.
Rolling back changes safely when problems arise""",
"""Demand forecasting and capacity planning should be in place to ensure that there is sufficient capacity and redundancy to serve projected future demand with the required availability""",
"""Provisioning combines both change management and capacity planning. Provisioning must be conducted quickly and only when necessary, as capacity is expensive. This must also be done correctly or capacity doesn’t work when needed""",
"""It is important to make efficient use of resources at any time a service focuses on money. Because SRE ultimately controls provisioning, it must also be involved in any work on utilization, as utilization is a function of how a given service works and how it is provisioned""",
"""Although the benefits of the SRE model are clear, large organizations often struggle to implement it. To overcome these challenges, large organizations can take the following five-step systematic approach.""",
"""Discover: The SRE Implementation starts off with the Discover Phase. In this phase, the focus is on baselining the current state of the organization, including the maturity of the processes, team skills and tool availability""",
"""Define: The Second phase of SRE Implementation is Define that involves defining an SRE Operating Model that includes the team structure, roles and responsibilities, and an interaction model with a view of the target state""",
"""Implement: This phase sees the first stage of the model become reality, with the team starting to work on an SRE construct a SRE Backlog. The team will be supported by monitoring SLOs and SLIs, and they will start focus on the automation of routine tasks.""",
"""Adopt: In this phase the model is expanded to Business teams and Development teams, causing them to experience a significant cultural shift and nd migration from traditional thinking to new ways of working. It is critical to have significant support from senior leadership throughout this stage.""",
"""Scale: The last phase of the implementation is Scaling. Once the organization has buy-in from all stakeholders, the model is ready to scale to wider units and services. At this point, teams should have ironed out the finer aspects of their interactions and be equipped to work seamlessly..""",
"""Although the benefits of the SRE model are clear, large organizations often struggle to implement it. To overcome these challenges, large organizations can take the following five-step systematic approach. The initial promise of AI is fast becoming reality. SRE teams are starting to apply AI to create intelligent IT operations as ML models reliably detect patterns and build insight from past experience. AI and automation applied to operations, AIOps, help teams manage the vast volumes of data and achieve proactive incident resolution.""",
"""AIops is creating a whirlwind across companies. It helps the companies in the Below way:
Deliver a single, intelligent and automated layer of intelligence across IT operations.
Collect and synthesize the ever-increasing volumes of operations data.
Intelligently identify significant events and patterns based on real-time analysis and past
experience.
Diagnose incident causes for rapid response and remediation.
Pinpoint affected application components to focus teams on stabilizing critical user
experiences.
Enable SREs to respond more quickly—even proactively—to incidents and outages
"""
]

# %%
for p in paras:
  inputs = tokenizer([p], return_tensors='pt')

# Generate Summary
  question_ids = model.generate(inputs['input_ids'], num_beams=1, early_stopping=True)
  print("Derived Question: \n\n", tokenizer.batch_decode(question_ids, skip_special_tokens=True))
  print("\n")
  print("Question Derived from this Content: \n\n", p)
# Out:
# Derived Question:
#
#  ['what does sre stand for?']
#
#
# Question Derived from this Content:
#
#  Site reliability engineering (SRE) is a software engineering approach to IT operations. SRE teams use the software as a tool to manage systems, solve problems, and automate operations tasks. SRE takes the tasks that have historically been done by operations teams, often manually, and instead gives them to engineers or ops teams who use software and automation to solve problems and manage production systems. SRE is a valuable practice when creating scalable and highly reliable software systems. It helps you manage large systems through code, which is more scalable and sustainable for sysadmins managing thousands or hundreds of thousands of machines.
# Derived Question:
#
#  ['what is a service level agreement?']
#
#
# Question Derived from this Content:
#
# ...

# %%
# !sudo apt-get update
# !sudo apt-get install build-essential libpoppler-cpp-dev pkg-config python-dev
# !pip install pdftotext
import pdftotext
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [62.9 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# ...

# %%
pdfs = ["1_AI Defined - Academic Perspective and Industry Perspective.pdf",
        "2_Real World Applications of AI.pdf",
        "3_How AI Applied in Industry.pdf",
        "4_Present and Futuristic State of AI.pdf",
        "5_Role of Mathematics and Statistics in AI.pdf",
        "6_Role of Data Science.pdf",
        "7_Intelligent Automation.pdf",
        "8_Digital Transformation of AI.pdf",
        "9_Introduction to Machine Learning.pdf",
        "10_AI Implementation Framework.pdf",
        "11_AI Business Case Development.pdf",
        "12_Social Awareness of AI, AI on Government and Public Policy.pdf",
        "13_AI Readiness and Awareness.pdf"]

from tika import parser
for pdf in pdfs:
    with open(pdf, "rb") as f:
        pdf = pdftotext.PDF(f)
    print(len(pdf))
    for page in pdf:
        print(page)
    #    print(len(page))
    #print("\n\n".join(pdf))
    #texttt = " ".join(pdf)
    #texttt
# Out:
# 19
#                     Unit-1 AI Defined - Academic Perspective and Industry Perspective
#                          Unit-1
# AI Defined - Academic
#        Perspective and
# Industry Perspective
#                                                                                       PAGE 1
# ©DeepSphere.AI, Inc.| Confidential and Proprietary|DeepSphere.AI | DsSchoolOfAI.Com | Info@DeepSphere.AI
#
#                                      Unit-1 AI Defined - Academic Perspective and Industry Perspective
#                                       Unit Topics
#                                           AI Defined - Academic Perspective
#                                           AI Defined - Industry Perspective
#                                           Why AI Now?
#                                           Human Intelligence vs. Artificial Intelligence
#                                           Emotional Intelligence vs. Artificial Intelligence
# ...

# %%
# !pip install pdf2docx
# Out:
# ...
#      |████████████████████████████████| 146 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 49.9 MB 16 kB/s
# ...
#      |████████████████████████████████| 870 kB 43.4 MB/s
# ...
#      |████████████████████████████████| 5.6 MB 37.8 MB/s
# ...
#      |████████████████████████████████| 87 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 6.4 MB 17.5 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=f265ab3a3bc2eb22384338f41a0c32185bcb890660bb8aa4b313aeb8b1c3abe6
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184507 sha256=cc8611e3464ce21b0cef0c62ee52f6df09500e27c8563a846d14a49b45cd4966
#   Stored in directory: /root/.cache/pip/wheels/f6/6f/b9/d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
# Successfully built fire python-docx
# ...
#   Attempting uninstall: opencv-python
# ...

# %%
from pdf2docx import parse
pdf_file = "1_AI Defined - Academic Perspective and Industry Perspective.pdf"
word_file = "test.docx"
parse(pdf_file, word_file, start=0, end=None)
# Out:
# [INFO] Start to convert 1_AI Defined - Academic Perspective and Industry Perspective.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/19) Page 1
# [INFO] (2/19) Page 2
# [WARNING] Ignore Line "PAGE 2" due to overlap
# [WARNING] Ignore Line "©DeepSphere.AI, Inc.| Confidential and Proprietary|DeepSphere.AI | DsSchoolOfAI.Com | Info@DeepSphere.AI" due to overlap
# [INFO] (3/19) Page 3
# [WARNING] Ignore Line "Introduction to" due to overlap
# [WARNING] Ignore Line "PAGE 3" due to overlap
# [WARNING] Ignore Line "©DeepSphere.AI, Inc.| Confidential and Proprietary|DeepSphere.AI | DsSchoolOfAI.Com | Info@DeepSphere.AI" due to overlap
# [INFO] (4/19) Page 4
# [WARNING] Ignore Line "PAGE 2" due to overlap
# [WARNING] Ignore Line "©DeepSphere.AI, Inc.| Confidential and Proprietary|DeepSphere.AI | DsSchoolOfAI.Com | Info@DeepSphere.AI" due to overlap
# [INFO] (5/19) Page 5
# [WARNING] Ignore Line "PAGE 5" due to overlap
# ...

# %%
from pdf2docx import Converter
import os

# # # dir_path for input reading and output files & a for loop # # #

path_input = '/content/'
path_output = '/content/'

for file in pdfs:
    cv = Converter(path_input+file)
    cv.convert(path_output+file+'.docx', start=0, end=None)
    cv.close()
    print(file)
# Out:
# [INFO] Start to convert /content/1_AI Defined - Academic Perspective and Industry Perspective.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/19) Page 1
# [INFO] (2/19) Page 2
# [WARNING] Ignore Line "PAGE 2" due to overlap
# [WARNING] Ignore Line "©DeepSphere.AI, Inc.| Confidential and Proprietary|DeepSphere.AI | DsSchoolOfAI.Com | Info@DeepSphere.AI" due to overlap
# [INFO] (3/19) Page 3
# [WARNING] Ignore Line "Introduction to" due to overlap
# [WARNING] Ignore Line "PAGE 3" due to overlap
# [WARNING] Ignore Line "©DeepSphere.AI, Inc.| Confidential and Proprietary|DeepSphere.AI | DsSchoolOfAI.Com | Info@DeepSphere.AI" due to overlap
# [INFO] (4/19) Page 4
# [WARNING] Ignore Line "PAGE 2" due to overlap
# [WARNING] Ignore Line "©DeepSphere.AI, Inc.| Confidential and Proprietary|DeepSphere.AI | DsSchoolOfAI.Com | Info@DeepSphere.AI" due to overlap
# [INFO] (5/19) Page 5
# ...

# %%
# !pip install PyPDF2
# Out:
# ...
#      |████████████████████████████████| 77 kB 2.8 MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61100 sha256=2942b70088bc277367846dc6a2a170dc72c5b2802df1ac7d37d2ce0a23d14129
#   Stored in directory: /root/.cache/pip/wheels/80/1a/24/648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# ...

# %%
import PyPDF2
import os
import docx

mydoc = docx.Document() # document type
pdfFileObj = open('1_AI Defined - Academic Perspective and Industry Perspective.pdf', 'rb') # pdffile loction
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) # define pdf reader object

# Loop through all the pages

for pageNum in range(1, pdfReader.numPages):
        pageObj = pdfReader.getPage(pageNum)
        pdfContent = pageObj.extractText()  #extracts the content from the page. 
        print(pdfContent) # print statement to test output in the terminal. codeline optional.
        mydoc.add_paragraph(pdfContent) # this adds the content to the word document
        
mydoc.save("AI Defined - Academic Perspective and Industry Perspective.docx") # Give a name to your output file.

# %%
paras = ["""Artificial Intelligence is the branch of computer science that attempts to approximate the results of human reasoning by organizing and manipulating factual and heuristic knowledge. Areas of AI activity include expert systems, natural language understanding, speech recognition, vision, and robotics and the branch of Computing Science concerned with simulating aspects of human intelligence such as language comprehension and production, vision, planning.""",
"""Artificial Intelligence is a computer system that can perform tasks that ordinarily require human intelligence. These artificial intelligence systems are powered by machine learning. Many of them are powered by machine learning, some of them are powered by specifically deep learning, some of them are powered by very boring things like just rules.""",
"""Today’s world is seeing a huge evolution in data. Large Unstructured data sets are handy for training AI models""",
"""Neural networks and parallel processing would be important development tools of AI""",
"""The emergence of AI models based on the use of the cloud makes field is so energized.""",
"""Artificial Intelligence models can solve complex & tedious problems accurately without skilled labor.""",
"""Industry needs an automated system which is performed by humans. AI replaces human intelligence.""",
"""Emotional intelligence is a subset of both intelligence and AI which understands emotions of others.""",
"""Social Awareness of Artificial Intelligence Artificial Intelligence is a daily topic of discussion. No Agreed definition of Artificial Intelligence. Picture of robots or other humanoid beings. Public Misreading as intention behind the technology. People often mistakenly conflate contemporary AI. Advent of AI will seriously disrupt labor force.""",
"""Public Policies and Awareness of AI Governments should invest in the development and adoption of AI. Governments need to also respond to the economic and societal challenges brought on by advances in AI. Automation, algorithmic bias, data exploitation, and income inequality are some challenges. The Government policies include investments into skills development, the creation of new regulations and standards. AI policy is not just the use of AI to improve the effectiveness of government policy or reduce costs. Depending on a country’s strengths & weaknesses, the government will choose to focus on different aspects of AI policy.""",
"""AI Challenges & Societal Impacts Enthusiasm & skepticism in minds. Automation taking away jobs. AI is a Black Box. 1 2 3 Data Sensitiveness. Non-skilled labor. 5 6 No provability of success guarantee.""",
"""Case management is the planning, processing, and monitoring of the healthcare services given to a patient by a coordinated group of healthcare providers. Case management is designed to provide for a patient’s needs while controlling costs, with a case manager maintaining information on a patient’s outcomes. Insurance companies, hospitals, and outpatient care providers may all assign a case manager to monitor a patient.""",
"""Business Impacts of Case Management Analytics Case Management Analytics helps healthcare in contract management Contract Management Case Management Analytics helps investigation of possible unethical or questionable behavior Compliance Tracking Case Management Analytics provides a holistic, flexible framework for handling case management projects.. Facilities Project Management""",
"""Case Management Analytics can improve the management of vendor information and content enhancing vendor performance Vendor Management Case Management Analytics tracks unreported incidents as a result if emerging risks & its resolution Incident Resolution Case Management Analytics identifies trends and areas of risk for thorough fraud investigations Fraud Investigation""",
"""Case Management Analytics helps healthcare in content management. Content Management Case Management Analytics helps healthcare in Knowledge Worker Interface. Knowledge Worker Interface Case Management Analytics helps healthcare in Task & Activity Management. Task and Activity Management""",
"""Advantages of having Case Management Analytics Increases Productivity Improve Visibility and control Effective Collaboration Improvement of health standards""",
"""Limitations of not having Case Management Analytics Healthcare organizations cannot Integrate disparate data. Healthcare organizations cannot Improve operational efficiencies. Healthcare organizations cannot Track and care for their patients and clients Healthcare cannot Provide resources for underserved populations.""",
"""Disease management is an approach to healthcare that teaches patients how to manage a chronic disease. Patients learn to take responsibility for understanding how to take care of themselves. They learn to avoid potential problems and exacerbation or worsening of their health problems.""",
"""Business Impacts of Disease Management Analytics Decrease in emergency room visits and hospitalizations ER Visits & Hospitalization Increase in Healthcare cost savings Cost Savings Improves patient’s Satisfaction & quality of life Patient Satisfaction & Quality of Life""",
"""Advantages of having Disease Management Analytics Improves quality care of chronic illness Facilitates healthy lifestyles Reduces hospitalizations Increases better contact with patients""",
"""Advantages of having Disease Management Analytics Achieves better compliance with treatment Reduces mortality & morbidity Improves patient disease control IImproves patient mood & emotions""",
"""Limitations of not having Disease Management Analytics 3 2 1 Increased Healthcare Costs Increases expenditures of time without compensation Limits Professional autonomy Characteristics""",
"""Customer churn or Customer Attrition is the percentage of customers that stopped using your company's product or service during a certain time frame. The Customer is treated to be churned once a particular amount of time has elapsed since the customer’s last interaction with the site or service.""",
"""Business Impacts of Customer Churn Analytics Decrease in Revenue Revenue Affects Customer Relationship Customer Relationship Affects valuation of the company or its products Valuation of the Company""",
"""Advantages of having Customer Churn Analytics Helps in predicting overall satisfaction of the customers Identifying potential network issues, competitive threats and at risk customers Identifies negative customer experience trends Helps in creating new opportunities for cross-selling and upselling""",
"""Limitations of not having Customer Churn Analytics 3 2 1 They cannot deliver tailored promotions and offers to positively influence their behavior. They cannot segment the customers based on behavior and demographics to improve retention Companies cannot access all customer-relevant data seamlessly and quickly They can't reduce acquisition costs & increase marketing efficiency""",
"""Vendor analysis is the assessment of current or prospective suppliers concerning their: Financial strength. Vendor’s business model. Capacity to supply the appropriate products and services. Capabilities – what it can and cannot do or provide. Turnover and profit levels.""",
"""Business Impacts of Vendor Performance Analytics Protects & improves brand reputations Brand Reputation Collaborate with Suppliers Supplier Collabortion Helps avoid chain risk disruptions Chain Risk Disruptions""",
"""Advantages of having Vendor Performance Analytics Increases performance visibility Uncover & remove hidden waste Leverage Supplier Base Align customer & business transactions""",
"""Limitations of not having Vendor Performance Analytics 3 2 1 Unsuccessful business with vendors who are willing to lower their prices Increases pre-delivery waiting period of customers Agile payment methods and terms offer payment No Flexible Supplier base""",
"""Sick wells are shut-in producers or underperforming wells. Analyzing these shut-in producing or underperforming wells at any point in time is called Sick well analytics. In any Oil & Gas field, at any given time, around 20% of the wells are sick due to mechanical failure, formation damage, reservoir problems, water encroachment, completion issues, lifting problems and so on""",
"""Business Impacts of Sick Well Analytics Reduced CAPEX / OPEX per barrel produced CAPEX/OPEX Production increase by reducing sick well inventory proactively Oil Production Improve oil production efficiency Efficiency""",
"""Advantages of having Sick Well Analytics Increases performance visibility Uncover & remove hidden waste It improves well efficiency It allows well modelling for production optimization""",
"""Limitations of not having Sick Well Analytics 3 2 1 The status of the wells could change during the study, but difficult to incorporate without sick well analysis The periodic process, results are not readily available Predicting underperformers in the early stage is not done Sick wells cannot not be proactively identified and revived""",
"""Drilling operations and rig costs are the major capital expenditures incurred in the drilling of an Oil & Gas well. Analysis of drilling data and events in an oil & gas well is called drilling analytics.""",
"""Drilling problems such as Stuck pipe, borehole collapse, circulation losses, etc cause major time, equipment, and monetary losses.""",
"""Non-Productive Time (NPT): NPT add 10-15% to the drilling cost. Waiting on equipment/materials, equipment and operation downtime are visible NPT, whereas pipe connection, BOP testing, etc contribute to invisible NPT when not optimized.""",
"""Equipment and Operations: Equipment failures such as Pumps, Engines, Drawworks, etc and Operations issues such as string failure, wellbore influx can be avoided in most cases if identified earlier and save cost and avoid NPT.""",
"""Business Impacts of Drilling Analytics Reduces Operating cost of drilling operations Operating Cost Minimizes Non-Productive Time Non Productive Time Reduces Operating downtime Downtime""",
"""Advantages of having Drilling Analytics Increase overall oil well efficiency Limited operational & equipment downtime Reduction in non-productive time Identification of Equipment failures""",
"""Limitations of not having Drilling Analytics 3 2 1 Proactive drilling optimization cannot be achieved Increase in Non-Productive Time Increase in Drilling cost Equipment failures cannot be analysed""",
"""Energy efficiency is using less energy to perform the same task that is, eliminating energy waste. While renewable energy technologies also help accomplish energy efficiency, improving energy efficiency is the cheapest and often the most immediate way to reduce the use of fossil fuels.""",
"""Business Impacts of Energy Efficiency Analytics Realize additional monetary and CO2 savings through reduced energy and maintenance costs. Savings Reduce energy consumption and detect inefficiencies, while increasing productivity Energy Consumption Make better decisions, reduce equipment failures and downtime, and improve maintenance Decision Making""",
"""Advantages of having Energy Efficiency Analytics Reduces greenhouse gas emissions Reduces demand for energy imports It Lowers costs on a household and economy-wide level Reduced energy consumption""",
"""Limitations of not having Energy Efficiency Analytics 3 2 1 Energy Efficiency Analytics promotes data-driven decision making Energy Efficiency Analytics can highlight energy savings Energy Efficiency Analytics gives insights to Equipment level Energy Consumption Energy Efficiency Analytics gives a massive insight to Energy costs""",
"""Demand response is a strategy used by electric utility companies to reduce or shift energy consumption from peak hours of the day when the demand for electricity is more. Demand response involves allowing customers to choose nonessential loads, which can be shed by the customers themselves or by the utility, at peak times. Demand Response analysis earns you revenue incentives to offset energy costs. Improves the reliability of the grid. Less demand means less stress on energy transition and distribution systems,. As demand for power decreases, less efficient and often more expensive forms of electricity generation are not needed, which helps keep energy costs in check.""",
"""Advantages of having Demand Response Analytics Significantly change how such targeting is done Helps analyze the entire customer base to find customers suitable for demand response Helps analyze individual customer usage behavior Reduced energy consumption & savings""",
"""Limitations of not having Demand Response Analytics 3 2 1 High Demand & low demand energy consumers cannot be identified Consumer energy consumption pattern cannot be ascertained Consumers Energy Demand cannot be tracked With Energy Demand Analytics in place only required energy will be supplied and used.""",
"""Crime detection normally falls into three distinguishable phases: the discovery that a crime has been committed, the identification of a suspect and the collection of sufficient evidence to indict the suspect before a court. Crime prevention is the deployment of various solutions in operational practices, physical barriers and technological equipment for preventing and reducing crime and criminal activities as well as deterring crime and criminals.""",
"""Advantages of having Crime Detection Analytics A crime that’s most committed can be identified hence a specific law can be enforced Crimes can be detected as and when they are committed Predicting Future crime spots can be identified Reduced energy consumption & savings""",
"""Limitations of not having Crime Detection Analytics 2 1 Increase in Crime Rate Situational awareness by delivering information to the field where the crime is committed cannot be ascertained""",
"""Cybersecurity is the practice of protecting systems, networks, and programs from digital attacks. These cyberattacks are usually aimed at accessing, changing, or destroying sensitive information; extorting money from users. Implementing effective cybersecurity measures is particularly challenging today because there are more devices than people, and attackers are becoming more innovative.""",
"""Advantages of having Crime Security Analytics Analyze security events that detect a threat before it has a chance to impact infrastructure Cybersecurity Analytics provides enhances Proof of compliance during an audit. Predicting Future crime spots can be identified Maintaining regulatory compliance""",
"""Limitations of not having Cyber Security Analytics 2 1 Threat to cybersecurity is data leak, which can be extremely damaging to both an individual or business Another cybersecurity threat for businesses is ransomware""",
"""Automation That Occurs Without Any Human Involvement and Manual Work""",
"""Cars will be driven automatically without ant driver's assistance. Has Object Detection features Has Lane Detection features Intelligent Automation Applications Percieve Atuate Decide Understand Sensor Data Initiate Actions Choose ActionsCars will be driven automatically
without ant driver's assistance.
Has Object Detection features
Has Lane Detection features""",
"""Personalized Customer experience Understanding Customers Interest Product Recommendation""",
""". Data Analytics is the process of analyzing raw data to find hidden insights within it. many different goals.
Data analytics is the science of analyzing raw data in order to make conclusions about that
information.
The techniques and processes of data analytics have been automated into mechanical
processes and algorithms that work over raw data for human consumption.
Data analytics help a business optimize its performance.
""",
"""Data Science Vs Data Analytics Data Science deals with Processing, cleaning, and validating the integrity of data Data Analytics deals with Collecting and interpreting data Data Data Science Data Analytics Scope Data Science deals with Performing Exploratory Data Analysis on large datasets Data Analytics deals with identifying relevant patterns in a dataset. Data Science deals with performing data mining by creating ETL pipelines. Data Analytics deals with performing data querying using SQL. Data Mining Analysis Data Science deals with statistical analysis using ML algorithms. Data Analytics deals with experiment with different analytical tools like predictive analytics Tools Business insights are gained using ML tools and algorithms Data visualization tools like Tableau, IBM Cognos Analytics are used for presenting the extracted information.""",
"""Data Science Vs Business Analytics Data Science deals with Processing, cleaning, and validating the integrity of data Data Analytics deals with Collecting and interpreting data Focus Businessa Analytics Data Science Process Data Science deals with Performing Exploratory Data Analysis on large datasets Data Analytics deals with identifying relevant patterns in a dataset. Data Science deals with performing data mining by creating ETL pipelines. Data Analytics deals with performing data querying using SQL. Data Sources Data Quality Data Science deals with statistical analysis using ML algorithms. Data Analytics deals with experiment with different analytical tools like predictive analytics Data Model Business insights are gained using ML tools and algorithms Data visualization tools like Tableau, IBM Cognos Analytics are used for presenting the extracted information.""",
"""Challenges: Learning Curve for New Technology Dilemma: Data Engineer or Data Scientist Where does the Analytics end up?""",
"""Learning Curve for New Technology: Each area of data science has a huge learning curve with the pace of the technology being pretty rapid. The target audience of any data science implementation sometimes needs to have a strong technical background/skills which is inevitable. The software packages/tools used in the implementation are built in different programming language hence there exists a steep learning curve.""",
"""Data Engineer or Data Scientist: It a quite a challenge for a business on deciding who do they mostly have in their team a data engineer or a data scientist? Data scientists often have strong technical skills, but lack knowledge of business and its products. Engineering and science groups have knowledge of the business and its products but may not be experienced with machine learning""",
"""Where Does an Analytic End Up: A well developed analytic or machine learning model has limited value to the business if it cannot be integrated with the business’s systems, products, and services""",
"""Empowering Management and Officers to Make Better Decisions: Data Science Implementation facilitates improved decision-making processes across the entire organization through effective communication and demonstrates the value of the companies data through measuring, tracking, and recording Key performance indicators and other information.""",
"""Directing Actions Based on Trends: During a Data Science Implementation organization’s data are explored and examined then certain actions are prescribed that will help improve the company’s performance""",
"""Challenging the Employees to Adopt Best Practices and Focus on Issues That Matter: Data Science team must be familiar and well-versed with the organization’s analytics product. The employees are trained for success with the demonstration of the effective use of the system to extract insights and drive action.""",
"""Identifying Opportunities: Existing processes and assumptions are to be deeply examined for developing additional methods and analytical algorithms. This requires the data science team to continuously and constantly improve the value that is derived from the organization’s data.""",
"""Identification and Refining of Target Audiences: Companies collect at least one source of customer data that is to analyzed. The importance of data science lies on the ability to take existing data on its own and combine it with other data points to generate insights an organization needs about its customers and audience.""",
"""Recruiting the Right Talent for the Organization: Vast amount of data is to be analyzed for picking the right talent and even sophisticated data-driven aptitude tests and gamesdata science can help your recruitment team make speedier and more accurate selections""",
"""Data Science Business Benefits Smarter Decision Better Product Making Efficient Business Management Predicting Outcomes Leveraging Data for Business Decisions Assesssing Business Decisions Talent Acquisition Automation Customer Retention""",
"""Any Data Science Implementation starts with Data Collection and progresses all the way through to Data Visualization. There are a number of technologies involved in during these steps of implementation. A High-level Architecture of Implementation technologies are enumerated in the below diagram:""",
"""GEE127 Data Science Implementation Tecnnologies Data Science Implementation Technologies Data Collection Implementation Technologies Collect Data from different Data source including Databases, Datawarehouse, CRM. SAP HANA SAP BW CRM Data Provisioning Load Data from different Data source including Databases, Datawarehouses, CRM etc into HDFS SAP HANA SAP BW CRM HDFS Data Preparation Data Mapping, Data Conversion, Data Quality Python R Programming Scala Model Engineering Load Data into Python DF. Perform Feature Engg. Model training, Model Testing & model outcome Python Scikit-Learn Tensorflow Keras Data Visualization Trend Analysis Comparision Analysis Forecasting Root Cause Analysis SAP SAC Google Data Studio Tableau S t e p H""",
"""Patient Readmission - Lifecycle Patient Readmission Physician Consultation Patient Admission Patient Medical Procedure/Surgery Patient Developing Complications Patient Discharge""",
"""Steps of Implementation Step - 1 Step - 2 Step - 3 Step - 6 Step - 5 Step - 4 Step - 7 Step - 8 Step - 9 Tableau Set up Python & Analytics Dev Environment. Ex: SAP SAC, Sources Data Collection - Collect Patient data from different Transform data including Mapping, Conversion Data TransformationIdentify the Problem for Predictive Analytics. Ex (Patient Readmission) Prepare data including data Modelling Data Preparation - Create Dashboard then Publish and share it to the business stakeholders (Ex: SAP HANA) Data LoadingData Load into the target after transformation Identify the Dimensions & KPI's for Analysis (Ex: Patient, Patient Readmission Rate) Engg. Write the model outcome to a persistant storage. Perform Feature/ Model""",
"""Step 1: Set up Python & Analytics Development Environment. - The first step of Patient Readmission Analytics implementation is setting up the development for machine learning modelling and the analytics framework. EX; Python and SAP SAC.""",
"""Step 2: Data Collection - Collect Patient data from different Sources: Patient and other related Data resides in multiple sources. EX: Patient Data in a RDBMS and their medical history details in a HDFS Filesystem, hence we need to connect to these sources & collect data.""",
"""Step 3: Data Transformation - Transform data including Mapping, Conversion: Once the raw data is collected it is to be transformed including checking the quality of the data, mapping to the target and converting etc.""",
"""Step 4: Data Loading- Data Load into the target after transformation (Ex: SAP HANA): The Transformed raw data is then loaded into the target system ex a RDBMS or a Data Warehouse for further processing.""",
"""Step 5: Data Preparation - Prepare data including data Modelling: The Transformed datasets are then modelled using Business Intelligence/Data Modelling tools EX: SAP HANA, Informatica etc..""",
"""Step 6: Identify the Problem for Predictive Analytics. Ex (Patient Readmission): Identify/Formulate the Business problem we are going to solve. Ex: Patient Readmission rate.""",
"""Step 7: Perform Feature and Model Engineering: Now that we have our development environment setup, its time to get started with the build process, first with feature engineering and then model engineering including model training, testing, validation et.""",
"""Step 8: Identify the Dimensions & KPI's for Analysis (Ex: Patient, Patient Readmission Rate): Once the machine learning models are implemented and results are written into persistent storage we can then identify all the Dimensions and measures required for analysis.""",
"""Step 9: Create Dashboard then Publish and share it with the business stakeholders: The final step of the implementation process is building the dashboards with identified Dimensions and KPI's for the business problem we are solving. Then once the build is complete the results are verified and the dashboard is published to the analytics server and shared to the business users or stakeholders.""",
"""Data Science Applications Consumer Healthcare Finance Manufacturing Banking Transport Medical Image Analysis Drug Discovery VIsual Assitants Product Recommendation Customer Segmentation Sentiment Analysis Maintenance Scheduling Machine Failure Analysis Monitoring systems Fraud Detection Credit Risk Monitoring Predicting Loan Sanctioning Custimers Strategic Decision Making Algorithmic Trading Risk Analytics Self Driving Cars Personalized Travel Logistics Analysis""",
"""Digital Transformation is paying off the business in a big way. They are seeing tangible benefits from their digital efforts and it reveals that enabling technologies they are using to achieve success.""",
"""Digital Transformation has improved business agility on a global scale. Business are seeing marked improvements in speed-to-market and time-to-decision.""",
"""What Impact digital transformation has on the business growth?""",
"""Digital Transformation Framework Customer Strategy Culture Experience Technology Process & Skills Customer is the centre of all Strategy is set of actions taken to bring value and experience to the customers Changing Culture has impact on people Disruptive Technologies for leveraging new trends Customer Experience, a smarter solution is need of the hour With new strategies, technologies, different ways of working, changing cultures, people have to be empowered with new processes and skills to support Digital Transformation.""",
"""Digital Transformation Applications GENERAL ELECTRIC Digital Manufacturing AIRBUS Microsatellites""",
"""Digital Transformation is paying off the business in a big way. They are seeing tangible benefits from their digital efforts and it reveals that enabling technologies they are using to achieve success.""",
"""Online advertisements and recommendations: AI helps generate product recommendations of what users may like based on the previous shopping experiences and search history of people,""",
"""Smartphone assistants: Voice assistants utilize AI to provide personalized service to users. These virtual assistants have the ability to answer questions, provide suggestions, and help users organize their tasks.""",
"""Healthcare: By using AI to analyze large quantities of data, better diagnosis is achieved by discovering new patterns enabling health providers to deliver faster care cost-effectively.""",
"""Artificial Intelligence has come a long way since the victory of DeepBlue over Kasparov notoriously. The development of Artificial Intelligence is fast progressing towards a moment when the boundaries between humans and machines will be erased. The advances and the growth in AI, can help computers translate human conversations, recognize photos and faces, or simply be your personal assistant.""",
"""The early adopters of Artificial Intelligence are investing heavily in analytics to ensure that the quality of algorithms and data can scale across their enterprise-wide information and knowledge needs. Some of the top-notch companies of the world are using Artificial Intelligence to plan new businesses and streamline existing processes all have solid senior management support for each A.I. initiative""",
"""The Enetertainment and telecommunications industry have the highest expectations for A.I. to accelerate new product and service offerings of all industries tracked in the study.""",
"""The industries are now making use of AI-based technologies and solutions more than ever before even though they are not cheap and easy to implement.""",
"""The Industries are using NLP (Natural Language Processing ) chatbots that enable smaller brands to save resources and improve customer satisfaction.""",
"""Cloud-based AI-enhanced tools as software-as-a-service (SaaS) are available""",
"""The AI Applications are deployed through Mobile devices across industries, whether it’s in the form of voice assistants, or personalized shopping experiences, or warehouse management apps.""",
"""Artificial Intelligence is used to create intelligent applications, neuronal networks, AI platforms as a service, and AI cloud services.""",
"""Intelligent machines that can replicate human behavior may not yet be widely available, but subsets of AI such as machine learning (ML) and deep learning (DL) have found a wide range of applications in both enterprise and everyday settings. Here are some of the best-known implementations of AI""",
"""The role of AI curation is on Facebook. Apple, Amazon, and Google are some of the other household brands that integrate AI into their products and services.""",
"""Siri, Apple’s voice assistant, uses AI to better understand your commands and habits and become more helpful over time Gmail uses machine learning for security reasons to stop spam and other unwanted emails Google Translate uses statistical analysis of language patterns to provide more accurate translations.""",
"""Amazon uses AI to provide product suggestions and other predictions Netflix taps into the power of AI to provide suggestions and trends Google Maps uses AI to suggest better routes and means of transportation""",
"""The energy sector uses AI to produce cheaper and more efficient wind energy. For instance, Siemens developed machine-learning technology, taking advantage of researchers’ findings that huge wind turbines could use data on weather and component vibration to fine-tune themselves continually, for example, by adjusting the angles of rotor blades""",
"""Work safety is another application with companies increasingly using A.I. as a “guardian angel”, to safeguard employees in high-risk jobs. Systems, trained on hundreds of hours of employee sensor data, monitor conditions""",
"""Healthcare identifies tumors and track the spread of cancer (Arterys), detect eye conditions using retinal imaging (Google’s DeepMind) and even assist with the tricky business of diagnosing, or even predicting disease""",
"""One of the most spoken technical advancements achieved through the use of AI is selfdriving cars. Technology isn’t perfect yet, as with these developments and advancements it will take a while for public acceptance to bring automated cars into widespread use.""",
"""In the future, we might be able to augment ourselves with computers and enhance many of our own natural abilities. Artificial Intelligence will become useful for people with amputated limbs, as the brain will be able to communicate with a robotic limb to give the patient more control. This kind of cyborg technology would significantly reduce the limitations that amputees deal with on a daily basis.""",
"""Artificial intelligence is impacting the future of virtually every industry and every human being. Artificial intelligence is the main driver of emerging technologies like big data, robotics and IoT, and it will continue to act as a technological innovator for the foreseeable future""",
"""Machine learning and computer vision are the areas of Artificial Intelligence for the detection and classification of various “safety events,” will be the future. Today from a camera image, we might be able to infer 25 signals, but six months from now we’ll be able to infer 100 or 150 signals from that same image. The only difference is the software that’s looking at the image. This will be compelling and Every customer will be able to benefit from every other customer that we bring on board because our systems start to see and learn more processes and detect more things that are important and relevant""",
"""Linear Algebra is a branch of mathematics that lets you concisely describe coordinates and interactions of planes in higher dimensions and perform operations on them".""",
"""Linear Algebra is a foundation field. It is the notation and formalisms are used by other branches of mathematics to express concepts that are also relevant to AI.""",
"""Usage of Linear Algebra in AI Linear algebra is a practical way to frame optimization algorithms. Linear Algebra is used in gradient descent algorithms, least squares solutions, support vector machines. Linear Algebra is used to reduce the dimensionality of a data set, using a technique called Principal Component Analysis (PCA).""",
"""Linear Algebra can be used to process data to accomplish tasks such as graphical transformations, face morphing, object detection and tracking, audio and image compression, edge detection, blurring, signal processing etc.""",
"""Images and Photographs: A photograph or an image is an example of a matrix from linear algebra. Operations on the image, such as cropping, scaling, shearing, and so on are all described using the notation and operations of linear algebra.""",
"""One Hot Encoding: Linear Algebra is used to convert categorical data into numerical data in machine learning. It is used to encode categorical variables to make them easier to work with.""",
"""Linear Regression: Linear Algebra is used in describing the relationships between variables. It is often used in machine learning for predicting numerical values in simpler regression problems""",
"""Regularization: Linear Algebra is used in models that involve coefficients, such as regression methods and artificial neural networks, simpler models are often characterized by models that have smaller coefficient values.""",
"""Recommendation Systems: Linear Algebra is used in Predictive modeling problems that involve the recommendation of products.""",
"""Linear Algebra can be used to process data to accomplish such tasks as graphical transformations, face morphing, object detection and tracking, audio and image compression, edge detection, blurring, signal processing and hell lot of other tasks.""",
"""Linear algebra works as a computation engine in ML. Most ML algorithms use a classifier or regressor and train it by minimizing error between the value calculated by the nascent classifier and the actual value from the training data. This can be done either iteratively or using linear algebra techniques.""",
"""In the recommendation systems, data handling system a lot of data is handled and All of the techniques in current use involve some type of matrix decomposition, a fundamental class of linear algebra techniques (e.g., non-negative matrix approximation, and positive-maximum-margin-matrix approximation)""",
"""The concepts of Linear Algebra are crucial for understanding the theory behind Machine Learning, especially for Deep Learning. They give you better intuition for how algorithms really work under the hood, which enables you to make better decisions. Hence as an AI professional, you must master some of its concepts.""",
"""Calculus is an important field in mathematics and it plays an integral role in many machine learning algorithms. If one wants to understand what’s going on under the hood in your machine learning work as a AI Architect, one needs to have a solid grasp of the fundamentals of calculus".""",
"""Calculus is a intrinsic field of maths and especially in many machine learning algorithms.""",
"""Calculus is all about linear and nonlinear functions. It uses a linear equation into slope and y-intercept. You will also build up an intuition for what slope is and how to calculate the slope.""",
"""Usage of Calculus in AI Calculus is used the neural networks or regression algorithms. Differential Calculus is used in machine learning in order to find optimal solutions to problems. Integral calculus is used in Machine learning for determining the probability of events, For example in finding the posterior in a Bayesian model, or bounding the error in a sequential decision.""",
"""Gradient Descent: Derivatives are an important concept for machine learning. In the training process of many machine learning algorithms we use gradient descent. Gradient descent uses differential calculus to find the derivative of sum of errors to update the systems parameters a little bit in such a way that the error decreases as much as possible.""",
"""Maximum Likelyhood: Two of the most common problems in machine learning are maximum likelihood estimation and Bayesian inference. The most common methods for tackling them are expectation maximization and variational Bayesian inference""",
"""Gradient computations: Gradient computations are generally fed into numerical optimization algorithms and calculus is readily used to compute these, especially in the case of neural networks where we use chain rule to arrive at the Backpropagation Algorithm.""",
"""Numerical Optimization: Numerical Optimization is used to train models, given a dataset, that will be used to perform anything from inference to data generation to sequential decision making""",
"""Optimization: Calculus is used in optimization algorithms like Gradient decent , which uses derivatives to decide whether to increase or decrease weights in order to maximize or minimize some objective (e.g. a model’s accuracy or error functions).""",
"""Probabilities: Calculus is used to calculate probabilities of a variable over a range using integrals to decide and move/tweak certain values related to it.""",
"""Predictive Calculus in NLP: Calculus has a great amount of contribution in Natural language processing engines.""",
"""Calculus is used a plenty in AI (Machine learning , image recognition and all). As AI algorithms are nothing but simple mathematical function , whether it is a step function like ReLU or Optimization function like SGD (Stochastic Gradient Decent ) .""",
"""Gradient algorithms are used to solve a category of problems. Different types of algorithms fall under Classification, Regression and Clustering problems""",
"""Classification Algorithms: Classification, as the name suggests is the act of dividing the dependent variable (the one we try to predict) into classes and then predict a class for a given input.""",
"""Regression Algorithms: Regression problems, the output is a continuous quantity. Meaning that we can use regression algorithms in cases where the target variable is a continuous variable.""",
"""Clustering Algorithms: Clustering is to assign the input into two or more clusters based on feature similarity.""",
"""Usage of Gradient Algorithm in AI Algorithms are used for calculation, data processing, and automated reasoning and for making predictions. Algorithms are designed to allow computers to learn on their own (i.e., facilitate machine learning). Algorithms are simply mathematical instructions used for data processing & making predictions on the dataset.""",
"""Decision Tree is a type of supervised learning algorithm that is mostly used for classification problems. Surprisingly, it works for both categorical and continuous dependent variables.""",
"""Support vector machines are a classification algorithm. In this algorithm, we plot each data item as a point in an ndimensional space (where n is the number of features you have), with the value of each feature being the value of a particular coordinate.""",
"""This is a classification technique based on Bayes’ theorem with an assumption of independence between predictors In simple terms, a Naive Bayes classifier assumes that the presence of a particular feature in a class is unrelated to the presence of any other feature""",
"""This can be used for both classification and regression problems. However, it is more widely used in classification problems in the ML industry.""",
"""Gradient Algorithms takes a combination of inputs and outputs simultaneously in order to “learn” the data and produce outputs when given new inputs. Algorithms follow different approaches to learn depending on the data set and the problem that is being solved.""",
"""Face Detection: Classify parts of the image as a face and nonface and create a square boundary around the face.""",
"""Text and hypertext categorization: Text and hypertext categorization for both inductive and transductive models""",
"""Handwriting Recognition: Recognize handwritten characters used widely.""",
"""AI is designed to learn in the same way as a child. AI algorithms can find patterns and builds assumptions based on those findings.""",
"""This is called model-based learning, and it allows AI to make better decisions than humans because it can take many more factors into account and analyze them in milliseconds""",
"""Example: The statement that the probability of “heads” in tossing a coin equals one-half, according to the relative frequency interpretation, implies that in a large number of tosses the relative frequency with which “heads” actually occurs will be approximately one-half, although it contains no implication concerning the outcome of any given toss.""",
"""Usage of Probability in AI Probability is used in Classification models to predict a probability of class membership. Algorithms are designed using probability (e.g. Naive Bayes). Probability makes the Learning algorithms to make decisions (e.g. information gain). Sub-fields of study are built on probability (e.g. Bayesian networks).""",
"""Algorithms are trained under probability frameworks (e.g. maximum likelihood). Models are fit using probabilistic loss functions (e.g. log loss and cross entropy). Model hyperparameters are configured with probability (e.g. Bayesian optimization). Probabilistic measures are used to evaluate model skill (e.g. brier score, ROC)""",
"""Probability is required to effectively work through a machine learning predictive modeling implementation projects & use cases.""",
"""AI is about developing predictive models from uncertain data. Uncertainty means working with imperfect or incomplete information. Probability is used to work with uncertain data.""",
"""Probabilistic Models are fit using probabilistic loss functions play a vital role in AI Implementation.""",
"""Example: Maximum likelihood estimation is very important probabilistic framework is used for regression, classification and clustering machine learning algorithms.""",
"""Statistics is a tool in the hands of mankind to translate complex facts into simple and understandable statement of facts""",
"""1. Supply Chain: The bigger the concern, the greater the need of statistics. The problems like overstocking, untimely purchases will be solved by thee help of statistics.""",
"""2. Education: Statistics is necessary for the formulation of policies to start new courses, consideration of facilities etc.""",
"""Statistical data is the data which are collected for a given purpose is called statistical data; it usually deals with the quantitative information.""",
"""1. Primary Data: The data which is collected for the first time, for example the painting, photograph of the historical event""",
"""2. Secondary Data: The data from any other source for different purpose when we use the same data for various purpose then it is called secondary data. for example, exhibition catalog explaining the painting, documentary about historical event.""",
"""DESCRIPTIVE ANALYSIS: Descriptive analysis uses descriptive statistics which tells us what is happening on the past, it tells the actual information present in data. the main tool if descriptive statistics are mean, median, mode.""",
"""PRESCRIPTIVE ANALYSIS: Prescriptive analysis uses both descriptive as well as predictive statistics to prescribe or recommends the actions which must happen in future.""",
"""PREDICTIVE ANALYSIS: Predictive analysis uses inferential statistics which infer or predicts what is most likely happen in future.""",
"""The data can be represented either in the form of table as well as diagrams. The main aim is to represent the data, but by the diagrammatic representation there are several advantages such as, Easy to understand Save time Facilitate comparison Bird eye view of complex data. Long lasting impression""",
"""Bar Chart: The simple bar diagram represents the magnitude of a single factor according to time periods, places, etc., there will be multiple bar diagram, sub-divided bar diagram too. A bar graph may run horizontally or vertically. The important thing to know is that the longer the bar, the greater its value. Bar graphs consist of two axes. On a vertical bar graph, as shown above, the horizontal axis (or x-axis) shows the data categories.""",
"""Pie Chart: A Pie-chart is a circular diagram, which is divided into slices in order to explain or illustrate numerical proportions. In a pie chart, central angle, area and an arc length of each slice is proportional to the quantity or percentages it represents. Total percentages should be 100 and total of the arc measures should be 360°.""",
"""Sampling is a process or methodology used in statistical analysis, in which a predetermined number of observations are taken from a larger population. The methodology used to sample from a larger population depends on the type of analysis being performed.""",
"""Purpose of sampling is to gather maximum information about the population under consideration at minimum time and human power. Sampling is much important because it saves money In case of 100% inspection is not possible then we go for sampling. Hence the size of the sample depends upon some factors such as the purpose of sampling, heterogeneity of sampling units in population, resources available, precision of estimates required.""",
"""In cooking, if we want to check the taste of the dish, we just take some small quality and tasted it instead of taking the whole dish. This is called sampling.""",
"""Consider the example, a pack of 56 playing cards we are going to take randomly any 5 of the cards is known simple random sampling""",
"""Measures of central tendency is the measure the centre of a set of data. There are three common ways that we do this. • Mean • Median • Mode""",
"""Mean: The mean is defined as the sum of the numerical values of the observation divided by the total number of observations. The formula for calculating the mean is""",
"""In school, you may hear a teacher talk about the average score on a test.Let’s consider, the score of the test are 56,42,39,60,58.""",
"""That average score is an application of the mean, as the teacher added up all of the test scores and divided them by the number of people in the class.""",
"""Median: The median is defined as the 50th percentile point. In other words, it cuts the data set directly down the middle into two equal halves.""",
"""The way to obtain the median is • First rearrange the numbers in the data set from least to greatest. Then, use the formula, Median = size of item • If you end up with two numbers, take the mean of those two numbers.""",
"""Mode: The mode of a data set is the number that appears the most often. Consider the example,""",
"""A measure of dispersion indicates the scattering of data. It explains the disparity of data from one another, delivering a precise view of their distribution. The measure of dispersion displays and gives us an idea about the variation and the central value of an individual item""",
"""In other words, dispersion is the extent to which values in a distribution differ from the average of the distribution. It gives us an idea about the extent to which individual items vary from one another, and from the central value.""",
"""Absolute Measures: Absolute measures of dispersion are expressed in the unit of variable itself, like kilograms, rupees, centimeters, marks""",
"""Relative Measures: Relative measures of dispersion are obtained as ratios or percentages of the average. These are also known as coefficients of dispersion. These are pure numbers or percentages that are totally independent of the units of""",
"""“Correlation” measures both the strength and direction of the linear relationship between two variables. Correlation is a function of the covariance.""",
""". “Covariance” indicates the direction of the linear relationship between variables.""",
"""The only difference between the two is that correlation values are standardized whereas, covariance values are not""",
"""The correlation coefficient is also known as the Pearson product-moment is obtained by dividing the covariance of the two variables by the product of their standard deviations. The mathematical representation of the same can be shown in the following manner:""",
"""A distribution is simply a collection of data, or scores, on a variable. Usually, these scores are arranged in order from smallest to largest and then they can be presented graphically. Below are the types of distributions in statistics:""",
"""A Bernoulli distribution has only two possible outcomes, namely 1 (success) and 0 (failure), and a single trial. So the random variable X which has a Bernoulli distribution can take value 1 with the probability of success, say p, and the value 0 with the probability of failure, say q or 1-p.""",
"""Here, the occurrence of a head denotes success, and the occurrence of a tail denotes failure. Probability of getting a head = 0.5 = Probability of getting a tail since there are only two possible outcomes.""",
"""A binomial distribution can be thought of as simply the probability of a SUCCESS or FAILURE outcome in an experiment or survey that is repeated multiple times. The binomial is a type of distribution that has two possible outcomes (the prefix “bi” means two, or twice). For example, a coin toss has only two possible outcomes: heads or tails and taking a test could have two possible outcomes: pass or fail.""",
"""A normal distribution, sometimes called the bell curve, is a distribution that occurs naturally in many situations. The bulk of students will score the average (C), while smaller numbers of students will score a B or D. An even smaller percentage of students score an F or an A. This creates a distribution that resembles a bell (hence the nickname). The bell curve is symmetrical. Half of the data will fall to the left of the mean; half will fall to the right.""",
"""Poisson distribution is a probability distribution that can be used to show how many times an event is likely to occur within a specified period of time . In other words, it is a count distribution. Poisson distributions are often used to understand independent events that occur at a constant rate within a given interval of time.""",
"""The exponential distribution is often concerned with the amount of time until some specific event occurs. For example, the amount of time (beginning now) until an earthquake occurs has an exponential distribution. Other examples include the length, in minutes, of long distance business telephone calls, and the amount of time, in months, a car battery lasts. It can be shown, too, that the value of the change that you have in your pocket or purse approximately follows an exponential distribution.""",
"""A confidence interval is a bounds on the estimate of a population variable. It is an interval statistic used to quantify the uncertainty on an estimate. A confidence interval is different from a tolerance interval that describes the bounds of data sampled from the distribution. It is also different from a prediction interval that describes the bounds on a single observation. Instead, the confidence interval provides bounds on a population parameter, such as a mean, standard deviation, or similar.""",
"""Data science is a terminology used for the process of the extraction of clean information from raw data for the formulation of actionable insights.""",
"""Advantages of Data Science 1 2 3 4 5 Helps make better business Decisions Helps to Improve Performance Boosts Business growth and Development through Data Analysis Helps in Identifying Opportunities Helps Identify the Target Audience""",
"""Disadvantages of Data Science 1 2 3 4 5 Mastering Data Science is Very Difficult Data Science Requires Massive Domain Knowledge Privacy of the Data is in Danger Arbitary Data may yield inaccurate resuults Inappropriate Prediction leads to massive loss.""",
"""Data Science - Enterprise View Data science is all about using this data in creative ways to
generate business value.
Data science is a multidisciplinary mix of data inference, algorithm development,
and technology to solve analytically complex problems.
At the core is data. Tons of raw information, streaming in and
stored in enterprise data warehouses make up for it.
Data Science - Discovery of Data Insight: This aspect of data
science is all about uncovering findings from data. Diving in at a granular level to
mine and understand complex behaviors,
trends, and inferences.
It's about surfacing hidden insight that can help enable
companies to make smarter business decisions.
""",
"""Data Science – Underlying Process Communicate Visual Report Collect Raw Data Process Raw Data Data Cleansing Reality Data Product Models & Algorithms Data Analysis Make Decisions""",
"""Role of AI in Data Science 01 02 03 04 Tool for Data Science AI acts as a tool for data science Statistical Algorithms Data Science all use statistical learning algorithms Predictive Modelling AI helps in predictive models for data analysis Information Gathering AI helps key information gathering""",
"""Data Science Industry Usecases Digital Transformation Retail Insurance Energy Healthcare Omni Channel Customer Churn Patient Readmission Patient Adherence Fraud Detection. Claim Processing. Energy Efficiency Energy Benchmarking""",
"""Automation That Occurs Without Any Human Involvement and Manual Work""",
"""Cars will be driven automatically without ant driver's assistance. Has Object Detection features Has Lane Detection features""",
"""Personalized Customer experience Understanding Customers Interest Product Recommendation""",
"""Automate workflows involving document review and analysis, substantially reducing long turn-around times. Increases profitability by improving business efficiency, including those involving large teams. Processes data coming from electronic databases, Excel spreadsheets, "know your customer" data and more""",
"""Just because a task is performed by a nonhuman intelligent process, does not mean that it is intelligent automation. If the automation of a Business Process is self-driven, (without human intelligence), then detection and appropriate action is necessary when there is a change in Business Processes or Data, such an automation is called Intelligent Automation.""",
"""Instruction Driven Automation RPA with Instructions Tasks are performed by non human intelligence Ex: Robot This type of Automation may not be able to detect changes in business process or changes in data.""",
"""Patient Appointment Scheduling
In this a RPA bot schedules patient’ appointments based on diagnosis, doctor availability,
location, and other variables including financial statements and insurance information.
""",
"""Uses software to create repeatable instructions and processes to replace or reduce human interaction with IT systems. Automation software works within the confines of those instructions, tools, and frameworks to carry out the tasks with little to no human intervention. Automation is key to IT optimization and digital transformation. Modern, dynamic IT environments need to be able to scale faster than ever and IT automation is vital to making that happen.""",
"""Digital transformation is the process of using digital technologies to create new or modify existing business processes, culture, and customer experiences to meet changing business and market requirements. This reimagining of business in the digital age is digital transformation.""",
"""Digital transformation is the process of using digital technologies to create new or modify existing business processes, culture, and customer experiences to meet changing business and market requirements.""",
"""It transcends traditional roles like sales, marketing, and customer service. Instead, the digital transformation begins and ends with how you think about, and engage with, customers. As we move from paper to spreadsheets to smart applications for managing our business, we have the chance to reimagine how we do business how we engage our customers with digital technology on our side.""",
"""Uber as an example - Uber is linking customers with freelance drivers; a flexible and efficient way to match supply and demand. Private drivers are motivated by the fact that they keep 80% of the gains of the trip fare; Uber keeps only 20%""",
"""The traffic of the vehicles is powerfully oriented thanks to algorithms that allow the company to direct drivers anticipating intense traffic areas based on news, weather, cultural events""",
"""The functioning of Uber’s business model is highly based on “Big Data”, including its pricing system. It is a dynamic pricing policy which varies according to various elements: the time, specific events, etc.""",
"""Digital Transformation – Underlying Process Step -1 Step -2 Step -3 Step -4 Step -5 Step -6 Identification of Transformation Objectives Accessing Technology Enablers Envision Future Platform Master Digital Lifecycle Organize Digital Transformation Lifecycle Execute the Agile Journey to the Future""",
"""Role of AI in Digital Transformation AI helps drive economics and capabilities of any business AI components are integrated to cognitive technologies AI/ ML tools and techniques help in detecting project risks AI/ ML tools and techniques help in predictive planning AI make the digital business more competitive & efficient AI generates sustained growth & competitive advantage""",
"""Digital Transformation Industry Usecases Digital Transformation Customer Organization Process and Systems Product Omni Channel Digital Marketing Connected Product Pay per use Digital Collaboration Virtual Workforce Anytime Anywhere, Any Device Agile Approaches to work""",
"""Machine Learning is the art of teaching a machine to perform a task without being explicitly programmed. In other words machine learning is the task of making computers more intelligent without explicitly teaching them how to behave by identifying patterns in data.""",
"""In This Example, if We Train the Machine on the Student's Grade Data, the Machine Learns
the Patterns in the Student's Grade by Subject.
Cyclic
Irregularity
Seasonal
""",
"""As the name indicates the data undergoes supervision. The machine is trained with labels meaning the dataset is tagged with the right answers. Maps input to output based on the learning process""",
"""Linear Regression Logistic Regression Naive Bayes Classifier Decision Tree Regressor Decision Tree Classifier Support Vector Machines""",
"""Industry Use Cases Patient LOS at the Hospital Patient Health Risk Patient Readmission Rate Customer Churn Customer Spend Prediction""",
"""Unsupervised Machine Learning : As the name indicates the data does not undergo any supervision. The machine groups the unsorted data w.r.t to pattern & similarities present in the data.""",
"""Reinforcement Learning is about taking suitable action to maximize a reward in a particular situation. The reinforcement agent decides what to do to perform the given task. There is no training dataset involved. The agent learns from experience. Reinforcement learning is a continuous decision-making process. There is no supervisor, only a real number or reward signal. Agent's actions determine the subsequent data it receives""",
"""A business case is an end to end solution of product implementation, for the customer or stakeholder that the product you’re pitching is a good investment. The need for a business case is that it collects the proposal, outline, strategy in one single document and offers a full look at how the project will benefit the organization.""",
"""Healthcare Usecases Patient Health Risk Patient Financial Risk Patient Adherence Patient Readmission Rate Discharge Rate and LOS Fraud Detection""",
"""Learning Curve for New Technology: Each area of machine learning has a huge learning curve with the pace of the technology being pretty rapid. The user of any machine learning business case sometimes needs to have a strong technical background/skills which is inevitable. The software packages/tools used in the usecase implementation are built in different programming language hence there exists a steep learning curve.""",
"""ML Engineer or ML Scientist: It a quite a challenge for a business on deciding who do they mostly have in their team a ML engineer or a ML scientist? ML scientists often have strong technical skills, but lack knowledge of business and its products. Engineering and science groups have knowledge of the business and its products but may not be experienced with machine learning""",
"""Where Does the usecase implementation End Up: A well developed analytic or machine learning model has limited value to the business if it cannot be integrated with the business’s systems, products, and services.""",
"""Classification is a task that requires the use of machine learning algorithms that learn how to assign a class label to examples from the business problem. Example classifying emails as “spam” or “not spam.”""",
"""Binary Classification: Binary classification refers to those classification tasks that have two class labels""",
"""Multiclass Classification: Multiiclass classification refers to those classification tasks that have more than two class labels""",
"""Companies or Organizations often face huge customer attrition or churn. When customers leave the company, they not only lose the revenue from these customers but also loose the resources spent to acquire these customers at the first place. This is a serious concern for the companies.""",
"""In this Implementation we are trying to predict customers who are mostly likely to churn using machine learning modelling. This implementation helps the companies to know in advance the customers who are more likely to leave the business at some point in time. This helps the companies to come up with retention strategies and policies.""",
"""Steps of Implementation Step - 1 Step - 2 Step - 3 Step - 6 Step - 5 Step - 4 Step - 7 Step - 8 Step - 9 Tableau Set up Python & Analytics Dev Environment. Ex: SAP SAC, Sources Data Collection - Collect Patient data from different Transform data including Mapping, Conversion Data TransformationIdentify the Problem for Predictive Analytics. Ex (Customer Churn) Prepare data including data Modelling Data Preparation - Create Dashboard then Publish and share it to the business stakeholders (Ex: SAP HANA) Data LoadingData Load into the target after transformation""",
"""Step 1: Set up Python & Analytics Development Environment. - The first step of Patient Readmission Analytics implementation is setting up the development for machine learning modelling and the analytics framework. EX; Python and SAP SAC.""",
"""Step 2: Data Collection - Collect Patient data from different Sources: Patient and other related Data resides in multiple sources. EX: Customer Data in a RDBMS and their transaction details in a ERP system, hence we need to connect to these sources & collect data.""",
"""Step 3: Data Transformation - Transform data including Mapping, Conversion: Once the raw data is collected it is to be transformed including checking the quality of the data, mapping to the target and converting etc""",
"""Step 4: Data Loading- Data Load into the target after transformation (Ex: SAP HANA): The Transformed raw data is then loaded into the target system ex a RDBMS or a Data Warehouse for further processing.""",
"""Step 5: Data Preparation - Prepare data including data Modelling: The Transformed datasets are then modelled using Business Intelligence/Data Modelling tools EX: SAP HANA, Informatica etc.""",
"""Step 6: Identify the Problem for Predictive Analytics. Ex (Customer Churn): Identify/Formulate the Business problem we are going to solve. Ex: Patient Readmission rate.""",
"""Step 7: Perform Feature and Model Engineering: Now that we have our development environment setup, its time to get started with the build process, first with feature engineering and then model engineering including model training, testing, validation et.""",
"""Step 8: Identify the Dimensions & KPI's for Analysis (Ex: Customer, Customer Churn): Once the machine learning models are implemented and results are written into persistent storage we can then identify all the Dimensions and measures required for analysis.""",
"""Step 9: Create Dashboard then Publish and share it with the business stakeholders: The final step of the implementation process is building the dashboards with identified Dimensions and KPI's for the business problem we are solving. Then once the build is complete the results are verified and the dashboard is published to the analytics server and shared to the business users or stakeholders.""",
"""Linear Regression: Unlike Classification problems, regression problems deal with predicting a continuous variable meaning range of values. Linear regression involves the use of a best-fit line, for predicting a range of value. Ex: Patient Health Risk Score, Customer Sales Revenue etc.""",
"""Logistic Regression: Logistic Regression is used for binary classification problems. Logistic regression uses a sigmoid curve to show the relationship between the target and independent variables. Logistic regression works best with large data sets that have an almost equal occurrence of values in target variables. The dataset should not contain a high correlation between independent variables (a phenomenon known as multicollinearity), as this will create a problem when ranking the variables.""",
"""Ridge Regression: When there exits a high correlation between independent variables, ridge regression model. It is known as a regularization technique, and is used to reduce the complexity of the model.""",
"""With the ever-increasing in population, the need for health care services continues to grow in most developed countries. For making health care more affordable, policymakers and health organizations need to align financial incentives with the implementation of care processes based on best practices and the achievement of better patient outcomes. """,
"""For hospitals Admission management, the ability to predict the length of stay (LOS) as early as in the preadmission stage could prove vital to monitor the quality of inpatient care.""",
"""The length of stay (LOS) in hospitals is often used as an indicator of the efficiency of care and hospital performance.""",
"""It is generally recognized that a shorter stay indicates less resource consumption per discharge and cost-saving while post discharge care is shifted to less expensive venues.""",
"""Model selection  is the process of choosing between different machine/deep learning approaches e.g. Decision Tree, Logistic Regression, Artificial Neural Networks, etc. or choosing between different hyperparameters or sets of features for the same machine learning approach - e.g. deciding between the polynomial degrees/complexities for linear regression.""",
"""The choice of the actual machine learning algorithm (e.g. SVM or logistic regression) is less important than you'd think - there may be a "best" algorithm for a problem, but often its performance is not much better than other well-performing approaches for that problem.""",
"""Out of all the machine learning and deep learning models, the decision tree regression Model is selected & implemented.""",
"""As expected, hospital, LOS was predicted than median and average LOS. The median LOS is simply the median LOS of past admissions to a hospital. The most surprising aspect of this work was how the patient ICD-9 diagnoses played a more important role than age when predicting the length-of-stay. By far, the most challenging aspect of this project was the feature engineering of the ICD-9 diagnoses into a more practical and interpretable form of super categories.""",
"""An enterprise AI technology infrastructure should be built on modern architectural components such as CPU, Many Core processors, GPUs,  FPGAs,  and ASICs with interoperability to existing legacy systems.""",
"""CPU  – CPU code is written mostly for the sequential run (on one thread). EX: Microcontrollers use C-programming/ Assembly language, which means sequential processing.""",
"""GPU  – GPUs (Graphics processing unit) was used to render images, but now one can make use of their high computing capabilities in general-purpose computations. The main requirement for these is that they should be highly parallelizable.""",
"""FPGA  – FPGAs (Field-programmable gate array) outperforms GPU for fewer precision computations (less floating point or integer round off) The emerging low precision and sparse (a greater number of 0's) DNN algorithms offer orders of magnitude algorithmic efficiency improvement over the traditional dense FP32 DNNs.""",
"""ASIC  – ASICs (Application Specific Integrated Circuits) are specific chips (as the name suggests) used to implement both analog and digital functionalities in high volume or high performance.""",
"""Model Training Model Testing Model Re-training Model Re-testing Model Validation Model Acceptance Model Engineering involves the following processes:""",
"""We Show the Model with many examples from our Dataset to understand the relationship between the Label and its features thoroughly. In other words, it memorizes the entire input dataset perfectly. This process is called Model Training.""",
"""The model is trained with Training Data for Learning the Patterns in the Dataset and validated against the Validation Dataset, then tested with the data never seen. This process is referred to as Model Testing.""",
"""The Validation Dataset is a separate section of the same data set from which the training set is derived. The main advantage of using the Validation Dataset is to test the generalization ability of a trained model. Model validation is performed after model training. Along with model training, model validation aims to find an optimal model with the best performance.""",
"""Machine Learning models deal with Streams of Data. The Dataset it got trained for may be appended by a New Dataset that significantly differs from the one that it trained on. Then the Machine Learning Models needs to be accurate, scalable, repeatable and ready to go Kind so that it can efficiently integrate with the Information Systems.""",
"""For accurate model prediction, the data that it predicates must have a similar distribution as the data on which the model was trained. As data distributions are expected to change over time, deploying a model is a continuous process.""",
"""It is a great exercise to monitor the incoming data continuously and retrain the model on newer data if you find that the data distribution has deviated significantly from the original training data distribution.""",
"""If monitoring data to detect a change in the data distribution has a high overhead, then a simpler strategy is to train the model periodically, for example, daily, weekly, or monthly. This way, our predictions tend to upgrade based on the dataset you are using.""",
"""As the Model undergoes retraining, it would have learned the patterns from the new dataset, appended on it. Hence dataset needs to be appended as well.""",
"""The Retested Model predicts the results accurately now, as it was Re-Trained on the New Dataset. Hence, the performance of the model is upgraded.""",
"""Artificial intelligence still stirs a range of emotions for many organizations, right from optimism about increased business opportunities to confusion about its potential, to concerns about job displacement and potential bias.""",
"""Yet despite these hesitations, AI presents many opportunities from greater product and service innovation to improved decision making.""",
"""For the organizations to reap these benefits and advance AI within their firms, making a strong, solid business case around how AI delivers is key.""",
"""Presenting AI in terms that business leaders and the board will embrace requires elevating discussions above technical concepts and speaking to business benefits such as competitiveness, operational efficiency, and revenue growth.""",
"""As such several business cases have been pre-built to showcase what results could these reap in terms of measurable values. Some of the business cases across different industries are:""",
"""AI Driving Factors Helps Reduce Hospital Cost. Improvement of Resource Utilization Right Bed Allocation Helps Long Time Strategic Planning 1 2 3 4 Helps Healthcare in Cost Savings Right Resource Allocation""",
"""AI Proposed Solution The proposed solution for length of stay prediction enables an AI predictive models for in-hospital admissions. 1 Thepredictivemodelthatisbestsuitedto implementlengthofstaypredictionismachine learningdecisiontreepredictivemodel. 2 The solution should start with data stored in any relational database. The next immediate step is data extraction, modelling, pre-processing 4 Once the extraction, modelling & preprocessing are done, the immediate step is feature engineering. 5 After feature engineering, model engineering where the predictive model does the LOS prediction.""",
"""Measurable Business Values and ROI 144 medical records taken for prediction. Reduced the Mean LOS was 9.6 days. Analyzed that discharge destination had the greatest effect on LOS.""",
"""Mean LOS for patients with Medicaid (11.3 days) was significantly longer than for patients with commercial insurance and uninsured patients (every 9.3 days) and patients with Medicare (8.8 days).""",
"""Business Benefits of Length of Stay Prediction Length of stay prediction improves quality of inpatient care Lengthof stay prediction improvehospital performance Length of stay prediction improves quality of inpatient care Length of stay prediction helps in best resource planning & allocation Length of stay prediction can also facilitate management with higher flexibility in bed use Length of stay prediction helps in better assessment in the cost effective treeatment Length of stay prediction stratifies patient according to their risks for prolonged stays""",
"""AI areas such as machine learning (ML), big data and natural language processing are transforming different sectors of the economy. While business professionals and investors are clearly recognising the potential of AI, to what extent do consumers appreciate and understand this new generation of technologies.""",
"""In a recently taken survey of AI Adoption Two-thirds of people are worried that AI will result in jobs being lost to machines. It also showed the majority think that AI tools that recommend products to customers like one from amazon and Netflix are creepy. 59% were nervous about the way their personal data is collected and used since the rise of AI.""",
"""In a society premised on AI, we have to eliminate disparities, divisions, or socially weak people. The policy makers and managers of the enterprises involved in AI must have an accurate understanding of AI.""",
"""The knowledge for proper use of AI in society and AI ethics, taking into account the complexity of AI and the possibility that AI can be misused intentionally.""",
"""The AI user should understand the outline of AI and be educated to utilize it properly because AI is much more complicated than the already developed conventional tools.""",
"""It is necessary to establish an educational environment that provides AI literacy according to the following principles, equally to every person.""",
"""In order to get rid of disparity between people having a good knowledge about AI technology and those being weak in it, opportunities for education such as AI literacy are widely provided in early childhood education and primary and secondary education""",
"""The public’s ability to understand AI-enabled services, and how they work, is key to ensuring trust in the technology. Algorithmic Literacy must be a basic skill: Whether it is the curating of information in social media platforms or self-driving cars, users need to be aware and have a basic understanding of the role of algorithms and autonomous decision making. Such skills will also be important in shaping societal norms around the use of technology.""",
"""For example, identifying decisions that may not be suitable to delegate to an AI. Provide the public with information: While full transparency around a service’s machine learning techniques and training data is generally not advisable due to the security risk, the public should be provided with enough information to make it possible for people to question its outcomes.""",
"""Big questions ?? In the age of artificial intelligence, do our AI systems need empathy? If so, what are some use cases where empathy can be most helpful in AI Systems?. our emotions govern a large part of our intelligence. Neuroscientists confirm that emotional intelligence and cognitive intelligence share many neural systems for integrating cognitive, social, and affective processes. This study confirms what psychologists have suspected for decades: that there are interdependencies between emotional intelligence and general intelligence.""",
"""Empathy is a part of emotional intelligence. Empathy means the ability to understand or feel what another person is experiencing within their frame of reference. In the general scope of emotional intelligence, empathy is in self-awareness, social awareness, selfactualization, and transcendence.""",
"""Governments have started to rely on artificial intelligence (AI) to deliver services and improve operations, but the use of it to help shape policy is just beginning. The foundations of policymaking specifically, the ability to sense patterns of need, develop evidence-based programs, forecast outcomes, and analyze effectiveness fall squarely in AI’s sweet spot.""",
"""AI will not replace policymakers, but it can enable a comprehensive, faster, and more rigorous approach to policymaking in the short run. More broadly, AI can deliver on the promise of a government of the future that is more responsive and leaves no one behind. As AI enters the mainstream, these are tall but achievable aspirations for public policymaking""",
"""Policymaking is lengthy, political, and bureaucratic in nature. Policymaking is time-consuming in support of proposed policies or to prove their effectiveness. Policymaking is surrounded by Inefficiency, overlap, and contradictions""",
"""Policymaking is not a single activity but a cyclical six-stage process of identification, formulation, adoption, implementation, and evaluation. (See the exhibit.) At each stage, AI can help policymakers generate more value and impact.""",
"""AI tools can rapidly synthesize large amounts of data and detect patterns. This capability is especially useful during a crisis, Machine learning can generate insights in near real time, allowing public-sector leaders and policymakers to take swift action.""",
"""Governments routinely try to forecast the projected costs, benefits, and outcomes of policy options. AI can turbocharge this analysis by providing speedy insights on much smaller subsets of populations and geographic regions.""",
"""AI can play an important role in this stage, which is historically political. A legislative body passes a law; a regulatory agency issues a new rule. Armed with insights generated using AI during the prior stages, regulators and lawmakers will be better equipped to make moreinformed decisions.""",
"""A policy is only as good as its implementation. AI tools can help get policies implemented more efficiently through automation and near real-time analysis of feedback from the field""",
"""Policies are also only as good as the tweaks that are made following implementation to fix what is not working in the field. AI tools can speed up assessment of things that need to change by identifying where a policy could be falling short or subject to fraud.""",
"""Prevalent across the enterprise landscape, spanning industries and functions including IT, sales,, marketing, finance and accounting""",
"""Companies recognize the massive potential of AI to help them reimagine their value proposition""",
"""The growing role of AI in influencing industries is evident in health care as well""",
"""Only a select number of companies have attained maturity in their digital journey in AI adoption""",
"""A few companies have moved beyond experimentation and are leveraging AI to create new value.""",
"""in place the necessary organizational structures and processes to ensure the successful deployment of AI solutions""",
"""The first step in the journey to AI change management for your enterprise is to understand and address if there are any disparities between your vision for AI and the ability of your organization to follow through with it.""",
"""It is important to assess just how ready your enterprise is, in its current state, to build, deploy, adopt and benefit from AI-centric solutions.""",
"""Ideas for AI Transformation need to be communicated clearly and grounded in the realities of organizational capabilities. When they are not, even the best intentions can go away.""",
"""Business leaders must measure their current AI maturity and assess the availability of internal skills""",
"""A baseline empowers the current workforce to develop industry-leading AI solutions""",
"""Once a baseline is established on workforce readiness for building and adopting AI-led solutions, organizations need to start improving on these metrics – through internal training and external capability augmentation.""",
"""When bringing in a new recruiting process to the talent team, people focus on what the change is: what new tools are we using? How will the process be different? Most of the time, they do not focus as much on how to make the change stick. The traditional recruiting process starts with the requirement specification from the client. Once the recruitment team has the requirement specified, they start hunting for the talent.""",
"""The entire recruitment process is a manual process & it takes a lot of time (typically months) to close out a single open job position.""",
"""Hence change management is necessary to reap benefits from the emerging technologies & improve the overall recruitment process.""",
"""This can be achieved if the whole process is automated with the use of AI technologies""",
"""AI automates the entire recruitment process right from finding the right candidate for the open job position & closing it out.""",
"""A sponsor is often viewed as the figurehead of a change management initiative.""",
"""Sponsorship means much more than the occasional speech or signature""",
"""The Change will not achieve enough momentum to be successful if it isn't driven from above by senior management.""",
"""People need to understand that change is required and be given reasons why they need to change.""",
"""They need to have the knowledge and to accept that processes need to now work differently.""",
"""People need to understand that change is required and be given reasons why they need to change.""",
"""A healthy change management strategy ensures that organizational change is smoothly implemented and that the beneficial goal of the change is achieved""",
"""Change doesn't happen in isolation. It impacts the whole company and all those who interact with the company including partners and customers""",
"""The success of organizational change lies in the reactions people. So communicating the change, plays a great role.""",
"""Internal communication is the key to success during times of change, and why internal communications managers play the most important roles""",
"""It’s important to pair AI deployments with organizational change management""",
"""Stakeholders will need to have a complete understanding of the changes to continue being productive.""",
"""Continued success requires strong organizational change management and communication initiatives in place before, during and after AI implementations.""",
"""Organizations that experience the smoothest transitions start education early and tailor it to multiple stakeholder groups before anything is in place.""",
"""People throughout the organization must understand the benefits of adopting AI everyone from administrative personnel to key business stakeholders""",
"""Maximizing the value of AI means using technology to augment what the human workforce does""",
"""Identify "who needs to know what" through a needs assessment relating to change management at a minimum project team, senior leaders and front-line managers and supervisors. Align change management into competency models and personal development plans Deliver training to targeted groups. Create the groundwork for individual competencies that ultimately must be evident for the organization to build the competency. Integrate all key roles in change management, for instance senior leaders as sponsors and front-line managers as coaches to employees""",
"""Developing skills like resilience, emotional intelligence, is a great way to make your workforce change-ready.""",
"""It’s important to figure out which soft skills development training each employee needs most""",
"""Seminars and training programs offered can be a great way to teach employees what soft skills development"""

]

# %%
for p in paras:
  inputs = tokenizer([p], return_tensors='pt')

# Generate Summary
  question_ids = model.generate(inputs['input_ids'], num_beams=1, early_stopping=True)
  print("Derived Question: \n\n", tokenizer.batch_decode(question_ids, skip_special_tokens=True))
  print("\n")
  print("Question Derived from this Content: \n\n", p)
  print("====================================================================================================")
  print("====================================================================================================")
  print("====================================================================================================")
# Out:
# Derived Question:
#
#  ['what is the term for the branch of computer science that attempts to approximate the results of human reasoning']
#
#
# Question Derived from this Content:
#
#  Artificial Intelligence is the branch of computer science that attempts to approximate the results of human reasoning by organizing and manipulating factual and heuristic knowledge. Areas of AI activity include expert systems, natural language understanding, speech recognition, vision, and robotics and the branch of Computing Science concerned with simulating aspects of human intelligence such as language comprehension and production, vision, planning.
# ...
# Derived Question:
#
#  ['what is the definition of an artificial intelligence system?']
#
#
# Question Derived from this Content:
#
# ...

# %%
paras = ["""Lasso Regression: Like ridge regression, lasso regression is another regularization technique that reduces the model’s complexity. It does so by prohibiting the absolute size of the regression coefficient.""",
"""Polynomial Regression: Polynomial regression models a non-linear dataset using a linear model. It is the equivalent of making a square peg fit into a round hole.""",
""""Predicting Patient's Health risk". Health care Providers are Prioritizing health care interventions and current health care system structures are to be focused on a balance of improving quality and decreasing costs One of the common methods of determining where to intervene to reduce costs is by examining patients’ risk scores. A risk score is a number that is assigned to patients based on their demographics and diagnoses a numerical representation of how costly they are expected to be compared to the average patient.""",
"""Step 1: Set up Python & Analytics Development Environment. - The first step of Customer Churn prediction implementation is setting up the development for machine learning modelling and the analytics framework. EX; Python and SAP SAC.""",
"""Step 2: Data Collection - Collect Patient data from different Sources: Patient & other related Data resides in multiple sources. EX: Patient Data in the Medical Database & their history details in HDFS systems, hence we need to connect to these sources & collect data.""",
"""Step 3: Data Transformation - Transform data including Mapping, Conversion: Once the raw data is collected it is to be transformed including checking the quality of the data, mapping to the target and converting etc.""",
"""Step 4: Data Loading- Data Load into the target after transformation (Ex: SAP HANA): The Transformed raw data is then loaded into the target system ex a RDBMS or a Data Warehouse for further processing""",
"""Step 5: Data Preparation - Prepare data including data Modelling: The Transformed datasets are then modelled using Business Intelligence/Data Modelling tools EX: SAP HANA, Informatica etc..""",
"""Step 6: Identify the Problem for Predictive Analytics. Ex (Patient Risk Score): Identify/Formulate the Business problem we are going to solve. Ex: Patient Risk Score.""",
"""Step 7: Perform Feature and Model Engineering: Now that we have our development environment setup, its time to get started with the build process, first with feature engineering and then model engineering including model training, testing, validation et.""",
"""Step 8: Identify the Dimensions & KPI's for Analysis (Ex: Patient, Risk Score): Once the machine learning models are implemented and results are written into persistent storage we can then identify all the Dimensions and measures required for analysis.""",
"""Step 9: Create Dashboard then Publish and share it with the business stakeholders: The final step of the implementation process is building the dashboards with identified Dimensions and KPI's for the business problem we are solving. Then once the build is complete the results are verified and the dashboard is published to the analytics server and shared to the business users or stakeholders.""",
"""Clustering is an unsupervised machine learning problem. Clustering is a technique for discovering interesting patterns in data, such as groups of customers based on their behavior.""",
"""There are many clustering algorithms to choose from and no single best clustering algorithm for all cases. Instead, it is a good idea to explore a range of clustering algorithms and different configurations for each algorithm.""",
"""K-Means Clustering: K-Means Clustering is a type of clustering algorithm that involves assigning examples to clusters in an effort to minimize the variance within each cluster. A cluster refers to a collection of data points aggregated together because of certain similarities.""",
"""Hierarchical Clustering: Hierarchical clustering, also known as hierarchical cluster analysis, is an algorithm that groups similar objects into groups called clusters. The endpoint is a set of clusters, where each cluster is distinct from each other cluster, and the objects within each cluster are broadly similar to each other..""",
"""DBSCAN Clustering: DBSCAN (Density-Based Spatial Clustering and Application with Noise), is a density-based clustering algorithm that is used to identify clusters of any shape in a data set containing noise and outliers.""",
"""The basic idea behind the density-based clustering approach is derived from a human intuitive clustering method one can easily identify clusters in the datasets along with several points of noise, because of the differences in the density of points.""",
"""Distribution Model-Based Clustering: In Distribution, Model-Based Clustering Clusters are formed by identifying the probability of all the data points in the cluster from the same distribution (Normal, Gaussian). The most popular algorithm in this type of technique is Expectation-Maximization (EM) clustering using Gaussian Mixture Models (GMM).""",
"""Deep learning is a machine learning technique that teaches computers to do what comes naturally to humans: learn by example.""",
"""Deep learning is a key technology behind driverless cars, enabling them to recognize a stop sign or to distinguish a pedestrian from a lamppost.""",
"""In deep learning, a computer model learns to perform classification tasks directly from images, text, or sound.""",
"""Deep learning models can achieve state-of-the-art accuracy, sometimes exceeding human-level performance. Models are trained by using a large set of labeled data and neural network architectures that contain many layers.""",
"""This is achieved by updating the weights of the network in response to the errors the model makes on the training dataset.""",
"""Updates are made to continually reduce this error until either a good enough model is found or the learning process gets stuck and stops.""",
"""The process of training neural networks is the most challenging part of using the technique in general and is by far the most time consuming, both in terms of effort required to configure the process and computational complexity required to execute the process.""",
"""Model Testing refers to testing the model with the Test Dataset. The model is trained by updating the weights of the network in response to the errors the model makes on the training dataset and then validated against the Validation Dataset, then tested with the data never seen. This process is referred to as Model Testing. This process is similar to the one in machine learning.""",
"""In Deep Learning Model Validation refers to a process in which a trained model is validated against a Validation Dataset. The Validation Dataset is a separate section of the same data set from which the training set is derived. The main advantage of using the Validation Dataset is to test the generalization ability of a trained model. Model validation is performed after model training. Along with model training, model validation aims to find an optimal model with the best performance.""",
"""Deep Learning models deal with lot of Data. The Dataset it got trained for may be appended by a New Dataset that significantly differs from the one that it trained on. Then the Deep Learning Models needs to be accurate, scalable, repeatable and ready to go Kind so that it can efficiently integrate with the Information Systems.""",
"""As the Model undergoes retraining, it would have learned the patterns from the new dataset, appended on it. Hence the test dataset needs to be appended as well.""",
"""The Retested Model predicts the results accurately now, as it was Re-Trained on the New Dataset. Hence, the performance of the model is upgraded.""",
"""Natural Language Processing, or NLP for short, is broadly defined as the automatic manipulation of natural language, like speech and text, by software""",
"""Natural Language Processing is the technology used to aid computers to understand the human’s natural language.""",
"""It’s not an easy task for teaching machines to understand how we communicate.""",
"""The ultimate objective of NLP is to read, decipher, understand, and make sense of the human languages in a manner that is valuable.""",
"""Computer vision is a field of computer science that works on enabling computers to see, identify and process images in the same way that human vision does, and then provide appropriate output.""",
"""It is like imparting human intelligence and instincts to a computer. In reality though, it is a difficult task to enable computers to recognize images of different objects.""",
"""Robotic process automation  (RPA) is the application of technology that allows employees in a company to configure computer software or a “robot” to capture and interpret existing applications for processing a transaction, manipulating data, triggering responses and communicating with other digital systems.""",
"""Robotic Process Automation in Length of stay prediction is used for data extraction and migration.""",
"""It is a simple and cost-efficient solution to handle such challenges of data operations.""",
"""The capacity of RPA to integrate with different technologies makes it a reliable data specialist, which can thereby afford the ‘luxury’ of a holistic analysis of the transferred data."""

]

# %%
for p in paras:
  inputs = tokenizer([p], return_tensors='pt')

# Generate Summary
  question_ids = model.generate(inputs['input_ids'], num_beams=1, early_stopping=True)
  print("Derived Question: \n\n", tokenizer.batch_decode(question_ids, skip_special_tokens=True))
  print("\n")
  print("Question Derived from this Content: \n\n", p)
  print("====================================================================================================")
  print("====================================================================================================")
  print("====================================================================================================")
# Out:
# Derived Question:
#
#  ["what is another regularization technique that reduces the model's complexity?"]
#
#
# Question Derived from this Content:
#
#  Lasso Regression: Like ridge regression, lasso regression is another regularization technique that reduces the model’s complexity. It does so by prohibiting the absolute size of the regression coefficient.
# ...
# Derived Question:
#
#  ['what is the equivalent of making a square peg fit into a round hole?']
#
#
# Question Derived from this Content:
#
#  Polynomial Regression: Polynomial regression models a non-linear dataset using a linear model. It is the equivalent of making a square peg fit into a round hole.
# ...
# Derived Question:
#
#  ['what is the purpose of risk scores?']
#
#
# Question Derived from this Content:
#
# ...
